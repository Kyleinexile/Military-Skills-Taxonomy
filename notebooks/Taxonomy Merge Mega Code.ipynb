# %%
#!/usr/bin/env python3
"""
Military Skills Taxonomy Creator

This script processes ESCO skills and O*NET Military Crosswalk data to create
a merged dataset for LLM-based military skills taxonomy creation.

It performs the following steps:
1. Process O*NET Military Crosswalk to extract Air Force Specialty Codes (AFSCs)
2. Process ESCO skills data to extract structured skill information
3. Create mappings between AFSCs and relevant skills
4. Generate a structured output for LLM taxonomy creation
"""

import os
import csv
import json
import pandas as pd
from typing import Dict, List, Any
import logging
from datetime import datetime

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("taxonomy_creator.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# File paths
INPUT_DIR = r"C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild"  # Adjust if needed
OUTPUT_DIR = r"C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Input files with updated filenames
MILITARY_CROSSWALK_FILE = os.path.join(INPUT_DIR, "milx0724.csv")
ESCO_ONET_CROSSWALK_FILE = os.path.join(INPUT_DIR, "Original Crosswalk ESCO and ONet.csv")
ESCO_SKILLS_FILE = os.path.join(INPUT_DIR, "skills_en.csv")
ESCO_HIERARCHY_FILE = os.path.join(INPUT_DIR, "skillsHierarchy_en.csv")
ESCO_OCCUPATIONS_SKILLS_FILE = os.path.join(INPUT_DIR, "occupationSkillRelations_en.csv")

# Output files
PROCESSED_AFSC_FILE = os.path.join(OUTPUT_DIR, "processed_afsc_data.json")
PROCESSED_SKILLS_FILE = os.path.join(OUTPUT_DIR, "processed_skills_data.json")
MERGED_TAXONOMY_FILE = os.path.join(OUTPUT_DIR, "military_skills_taxonomy.json")

def process_military_crosswalk() -> List[Dict]:
    """
    Process the O*NET Military Crosswalk file to extract Air Force specialties.
    
    Returns:
        List of dictionaries containing processed AFSC data
    """
    logger.info(f"Processing Military Crosswalk from: {MILITARY_CROSSWALK_FILE}")
    
    afscs = []
    
    try:
        # Read CSV file
        with open(MILITARY_CROSSWALK_FILE, 'r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            rows = list(reader)
            
            # Count records by service
            service_counts = {}
            for row in rows:
                svc = row.get('SVC', '')
                service_counts[svc] = service_counts.get(svc, 0) + 1
                
            logger.info(f"Service counts in crosswalk: {service_counts}")
            
            # Filter for Air Force entries (SVC = 'F')
            air_force_rows = [row for row in rows if row.get('SVC') == 'F']
            logger.info(f"Found {len(air_force_rows)} Air Force entries")
            
            # Transform to structured format
            for row in air_force_rows:
                # Skip inactive records
                if row.get('STATUS') != 'A':
                    continue
                    
                # Extract O*NET and SOC codes and titles
                onet_codes = []
                onet_titles = []
                soc_codes = []
                soc_titles = []
                
                for i in range(1, 5):  # There are up to 4 O*NET and SOC mappings
                    if row.get(f'ONET{i}') and row.get(f'ONET{i}').strip():
                        onet_codes.append(row.get(f'ONET{i}'))
                        onet_titles.append(row.get(f'ONET{i}_TITLE', ''))
                    
                    if row.get(f'SOC{i}') and row.get(f'SOC{i}').strip():
                        soc_codes.append(row.get(f'SOC{i}'))
                        soc_titles.append(row.get(f'SOC{i}_TITLE', ''))
                
                # Create a combined description
                description_elements = []
                if row.get('MOC_TITLE'):
                    description_elements.append(row.get('MOC_TITLE'))
                if row.get('DODOCC_TITLE') and row.get('DODOCC_TITLE') != '-':
                    description_elements.append(f"DoD Occupation: {row.get('DODOCC_TITLE')}")
                for title in onet_titles:
                    if title and title not in description_elements:
                        description_elements.append(f"Related to civilian role: {title}")
                
                description = ". ".join(description_elements)
                
                # Extract keywords from titles
                keywords = set()
                for title in [row.get('MOC_TITLE', '')] + onet_titles + soc_titles:
                    if not title:
                        continue
                    # Simple keyword extraction by splitting and filtering
                    words = [w.lower() for w in title.split() if len(w) > 3 and w.lower() not in
                             ['and', 'the', 'for', 'with', 'all', 'other']]
                    keywords.update(words)
                
                # Create structured AFSC entry
                afsc_entry = {
                    'afscCode': row.get('MOC', ''),
                    'afscTitle': row.get('MOC_TITLE', ''),
                    'category': 'Enlisted' if row.get('MPC') == 'E' else 'Officer' if row.get('MPC') == 'O' else 'Warrant',
                    'description': description,
                    'onetCodes': onet_codes,
                    'onetTitles': onet_titles,
                    'socCodes': soc_codes,
                    'socTitles': soc_titles,
                    'keywords': list(keywords),
                    'source': 'O*NET Military Crosswalk'
                }
                
                afscs.append(afsc_entry)
            
        logger.info(f"Processed {len(afscs)} active Air Force specialties")
        return afscs
        
    except Exception as e:
        logger.error(f"Error processing Military Crosswalk: {str(e)}")
        raise

def process_esco_onet_crosswalk() -> Dict[str, Any]:
    """
    Process the ESCO to O*NET crosswalk file.
    
    Returns:
        Dictionary mapping between ESCO and O*NET concepts
    """
    logger.info(f"Processing ESCO to O*NET crosswalk from: {ESCO_ONET_CROSSWALK_FILE}")
    
    try:
        # Initialize mapping dictionaries
        esco_to_onet = {}
        onet_to_esco = {}
        
        # Read the crosswalk file
        df = pd.read_csv(ESCO_ONET_CROSSWALK_FILE, encoding='utf-8')
        
        # Log column names to understand the structure
        logger.info(f"ESCO-O*NET crosswalk columns: {', '.join(df.columns)}")
        
        # Determine the correct column names based on the file structure
        # This is flexible since we don't know the exact structure
        esco_code_col = next((col for col in df.columns if 'esco' in col.lower() and 'code' in col.lower()), None)
        onet_code_col = next((col for col in df.columns if 'onet' in col.lower() and 'code' in col.lower()), None)
        
        if not esco_code_col or not onet_code_col:
            # Try alternative column names
            possible_esco_cols = [col for col in df.columns if 'esco' in col.lower()]
            possible_onet_cols = [col for col in df.columns if 'onet' in col.lower()]
            
            if possible_esco_cols and possible_onet_cols:
                esco_code_col = possible_esco_cols[0]
                onet_code_col = possible_onet_cols[0]
            else:
                logger.warning("Could not identify ESCO and O*NET columns in the crosswalk file")
                return {'esco_to_onet': {}, 'onet_to_esco': {}}
        
        # Create mappings
        for _, row in df.iterrows():
            esco_code = str(row[esco_code_col]).strip()
            onet_code = str(row[onet_code_col]).strip()
            
            if esco_code and onet_code and esco_code != 'nan' and onet_code != 'nan':
                # Map ESCO to O*NET
                if esco_code not in esco_to_onet:
                    esco_to_onet[esco_code] = []
                if onet_code not in esco_to_onet[esco_code]:
                    esco_to_onet[esco_code].append(onet_code)
                
                # Map O*NET to ESCO
                if onet_code not in onet_to_esco:
                    onet_to_esco[onet_code] = []
                if esco_code not in onet_to_esco[onet_code]:
                    onet_to_esco[onet_code].append(esco_code)
        
        logger.info(f"Created mappings for {len(esco_to_onet)} ESCO codes to O*NET")
        logger.info(f"Created mappings for {len(onet_to_esco)} O*NET codes to ESCO")
        
        return {
            'esco_to_onet': esco_to_onet,
            'onet_to_esco': onet_to_esco
        }
        
    except Exception as e:
        logger.error(f"Error processing ESCO-O*NET crosswalk: {str(e)}")
        return {'esco_to_onet': {}, 'onet_to_esco': {}}

def process_esco_skills() -> Dict[str, Any]:
    """
    Process ESCO skills and hierarchy data.
    
    Returns:
        Dictionary containing processed skills data and hierarchy
    """
    logger.info(f"Processing ESCO skills from: {ESCO_SKILLS_FILE}")
    logger.info(f"Processing ESCO hierarchy from: {ESCO_HIERARCHY_FILE}")
    
    try:
        # Process skills
        skills_dict = {}
        skills_by_type = {}
        
        with open(ESCO_SKILLS_FILE, 'r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                skill_uri = row.get('conceptUri', '')
                if not skill_uri:
                    continue
                
                # Extract the verb (first word of skill name or description)
                preferred_label = row.get('preferredLabel', '')
                description = row.get('description', '')
                
                verb = ''
                if preferred_label:
                    verb = preferred_label.split()[0].lower() if preferred_label.split() else ''
                elif description:
                    verb = description.split()[0].lower() if description.split() else ''
                
                # Process alternate labels
                alt_labels_text = row.get('altLabels', '')
                alt_labels = [label.strip() for label in alt_labels_text.split('\n') if label.strip()]
                
                # Extract skill type and level
                skill_type = row.get('skillType', '')
                reuse_level = row.get('reuseLevel', '')
                
                # Organize by skill type
                if skill_type not in skills_by_type:
                    skills_by_type[skill_type] = []
                
                # Extract keywords from description
                keywords = []
                if description:
                    # Simple keyword extraction
                    words = description.lower().split()
                    # Filter out common words and short words
                    keywords = [word for word in words if len(word) > 3 and word not in 
                              ['and', 'the', 'for', 'with', 'this', 'that', 'which', 'what',
                               'where', 'when', 'who', 'how', 'such', 'from', 'their']]
                
                # Create skill entry
                skill_entry = {
                    'skillUri': skill_uri,
                    'skillName': preferred_label,
                    'skillType': skill_type,
                    'reuseLevel': reuse_level,
                    'description': description,
                    'altLabels': alt_labels,
                    'verb': verb,
                    'keywords': keywords
                }
                
                skills_dict[skill_uri] = skill_entry
                skills_by_type[skill_type].append(skill_uri)
        
        logger.info(f"Processed {len(skills_dict)} ESCO skills")
        logger.info(f"Skill types: {', '.join(skills_by_type.keys())}")
        
        # Process hierarchy
        hierarchy = {}
        skill_categories = {}
        
        with open(ESCO_HIERARCHY_FILE, 'r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                level0_uri = row.get('Level 0 URI', '')
                level0_term = row.get('Level 0 preferred term', '')
                level1_uri = row.get('Level 1 URI', '')
                level1_term = row.get('Level 1 preferred term', '')
                level2_uri = row.get('Level 2 URI', '')
                level2_term = row.get('Level 2 preferred term', '')
                level3_uri = row.get('Level 3 URI', '')
                level3_term = row.get('Level 3 preferred term', '')
                description = row.get('Description', '')
                
                # Create hierarchy entries
                if level0_uri and level0_term:
                    if level0_uri not in hierarchy:
                        hierarchy[level0_uri] = {
                            'uri': level0_uri,
                            'term': level0_term,
                            'description': description,
                            'children': {}
                        }
                
                if level0_uri and level1_uri and level1_term:
                    if level1_uri not in hierarchy[level0_uri]['children']:
                        hierarchy[level0_uri]['children'][level1_uri] = {
                            'uri': level1_uri,
                            'term': level1_term,
                            'description': description,
                            'children': {}
                        }
                
                if level0_uri and level1_uri and level2_uri and level2_term:
                    if level2_uri not in hierarchy[level0_uri]['children'][level1_uri]['children']:
                        hierarchy[level0_uri]['children'][level1_uri]['children'][level2_uri] = {
                            'uri': level2_uri,
                            'term': level2_term,
                            'description': description,
                            'children': {}
                        }
                
                if level0_uri and level1_uri and level2_uri and level3_uri and level3_term:
                    children = hierarchy[level0_uri]['children'][level1_uri]['children'][level2_uri]['children']
                    if level3_uri not in children:
                        children[level3_uri] = {
                            'uri': level3_uri,
                            'term': level3_term,
                            'description': description,
                            'skills': []
                        }
                
                # Map skills to categories
                if level3_uri and level3_term:
                    skill_categories[level3_uri] = {
                        'level0': {'uri': level0_uri, 'term': level0_term},
                        'level1': {'uri': level1_uri, 'term': level1_term},
                        'level2': {'uri': level2_uri, 'term': level2_term},
                        'level3': {'uri': level3_uri, 'term': level3_term},
                        'description': description
                    }
        
        # Count skills by hierarchy level
        level_counts = {'level0': 0, 'level1': 0, 'level2': 0, 'level3': 0}
        for level0_uri, level0_data in hierarchy.items():
            level_counts['level0'] += 1
            for level1_uri, level1_data in level0_data['children'].items():
                level_counts['level1'] += 1
                for level2_uri, level2_data in level1_data['children'].items():
                    level_counts['level2'] += 1
                    for level3_uri, level3_data in level2_data['children'].items():
                        level_counts['level3'] += 1
        
        logger.info(f"Processed hierarchy with counts: {level_counts}")
        
        # Process occupation-skill relations
        skill_to_occupations = {}
        occupation_to_skills = {}
        
        with open(ESCO_OCCUPATIONS_SKILLS_FILE, 'r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            for row in reader:
                occ_uri = row.get('occupationUri', '')
                skill_uri = row.get('skillUri', '')
                relation_type = row.get('relationType', '')  # essential or optional
                
                if not occ_uri or not skill_uri:
                    continue
                
                # Map skill to occupations
                if skill_uri not in skill_to_occupations:
                    skill_to_occupations[skill_uri] = []
                
                skill_to_occupations[skill_uri].append({
                    'occupationUri': occ_uri,
                    'relationType': relation_type
                })
                
                # Map occupation to skills
                if occ_uri not in occupation_to_skills:
                    occupation_to_skills[occ_uri] = []
                
                occupation_to_skills[occ_uri].append({
                    'skillUri': skill_uri,
                    'relationType': relation_type
                })
        
        logger.info(f"Processed {len(skill_to_occupations)} skill-to-occupation mappings")
        logger.info(f"Processed {len(occupation_to_skills)} occupation-to-skill mappings")
        
        return {
            'skills': skills_dict,
            'hierarchy': hierarchy,
            'skillCategories': skill_categories,
            'skillsByType': skills_by_type,
            'skillToOccupations': skill_to_occupations,
            'occupationToSkills': occupation_to_skills
        }
        
    except Exception as e:
        logger.error(f"Error processing ESCO skills: {str(e)}")
        raise

def create_afsc_skill_mapping(afscs: List[Dict], esco_data: Dict, crosswalk_data: Dict) -> List[Dict]:
    """
    Create mappings between AFSCs and ESCO skills.
    
    Args:
        afscs: List of processed AFSC data
        esco_data: Dictionary containing processed ESCO data
        crosswalk_data: Dictionary containing ESCO-O*NET crosswalk data
        
    Returns:
        List of AFSCs with mapped skills
    """
    logger.info("Creating AFSC to ESCO skill mappings")
    
    skills_dict = esco_data['skills']
    skill_to_occupations = esco_data['skillToOccupations']
    onet_to_esco = crosswalk_data.get('onet_to_esco', {})
    
    # Create lookup dictionaries for O*NET codes and titles
    onet_code_to_afsc = {}
    onet_title_to_afsc = {}
    
    for afsc in afscs:
        for code in afsc.get('onetCodes', []):
            if code not in onet_code_to_afsc:
                onet_code_to_afsc[code] = []
            onet_code_to_afsc[code].append(afsc['afscCode'])
        
        for title in afsc.get('onetTitles', []):
            if title not in onet_title_to_afsc:
                onet_title_to_afsc[title] = []
            onet_title_to_afsc[title].append(afsc['afscCode'])
    
    # Function to calculate match score between AFSC and skill
    def calculate_match_score(afsc, skill):
        score = 0
        
        # Keyword matching
        afsc_keywords = set(kw.lower() for kw in afsc.get('keywords', []))
        skill_keywords = set(kw.lower() for kw in skill.get('keywords', []))
        
        # Count matching keywords
        common_keywords = afsc_keywords.intersection(skill_keywords)
        score += len(common_keywords) * 2
        
        # Check if skill verb appears in AFSC title or description
        verb = skill.get('verb', '').lower()
        if verb and (
            verb in afsc.get('afscTitle', '').lower() or 
            verb in afsc.get('description', '').lower()
        ):
            score += 3
        
        # Check skill description against AFSC description
        skill_desc = skill.get('description', '').lower()
        afsc_desc = afsc.get('description', '').lower()
        
        for kw in afsc_keywords:
            if kw in skill_desc:
                score += 1
        
        for kw in skill_keywords:
            if kw in afsc_desc:
                score += 1
        
        # Check crosswalk data for additional matches
        # If this AFSC's O*NET codes map to this skill through the crosswalk, increase score
        for onet_code in afsc.get('onetCodes', []):
            esco_uris = onet_to_esco.get(onet_code, [])
            if skill.get('skillUri') in esco_uris:
                score += 5  # Higher score for direct crosswalk matches
        
        return score
    
    # Process each AFSC and find matching skills
    afsc_skill_mappings = []
    
    for afsc in afscs:
        logger.info(f"Processing AFSC {afsc['afscCode']}: {afsc['afscTitle']}")
        
        # Find candidate skills
        candidate_skills = []
        
        # Approach 1: Direct keyword matching
        for skill_uri, skill in skills_dict.items():
            match_score = calculate_match_score(afsc, skill)
            if match_score >= 3:  # Threshold for considering a match
                candidate_skills.append({
                    'skillUri': skill_uri,
                    'skillName': skill['skillName'],
                    'description': skill['description'],
                    'matchScore': match_score,
                    'matchMethod': 'keyword',
                    'verb': skill['verb'],
                    'skillType': skill['skillType']
                })
        
        # Sort candidates by match score
        candidate_skills.sort(key=lambda x: x['matchScore'], reverse=True)
        
        # Limit to top matches
        top_candidates = candidate_skills[:50]
        
        # Group skills by verb for better organization
        skills_by_verb = {}
        for skill in top_candidates:
            verb = skill.get('verb', '') or 'other'
            if verb not in skills_by_verb:
                skills_by_verb[verb] = []
            skills_by_verb[verb].append(skill)
        
        # Create the AFSC entry with mapped skills
        afsc_mapping = {
            **afsc,  # Include all original AFSC data
            'matchedSkills': top_candidates,
            'skillsByVerb': [
                {'verb': verb, 'skills': skills} 
                for verb, skills in skills_by_verb.items()
            ],
            'totalMatches': len(top_candidates)
        }
        
        afsc_skill_mappings.append(afsc_mapping)
    
    logger.info(f"Created skill mappings for {len(afsc_skill_mappings)} AFSCs")
    return afsc_skill_mappings

def create_taxonomy_data(afsc_skill_mappings: List[Dict], esco_data: Dict) -> Dict:
    """
    Create the final taxonomy data structure.
    
    Args:
        afsc_skill_mappings: List of AFSCs with mapped skills
        esco_data: Dictionary containing processed ESCO data
        
    Returns:
        Dictionary containing the complete taxonomy
    """
    logger.info("Creating final taxonomy data structure")
    
    # Organize AFSCs by category
    afscs_by_category = {}
    for afsc in afsc_skill_mappings:
        category = afsc['category']
        if category not in afscs_by_category:
            afscs_by_category[category] = []
        afscs_by_category[category].append(afsc)
    
    # Sort AFSCs within each category
    for category in afscs_by_category:
        afscs_by_category[category].sort(key=lambda x: x['afscCode'])
    
    # Extract top level skill categories from hierarchy
    skill_hierarchy = esco_data['hierarchy']
    top_level_categories = []
    
    for uri, data in skill_hierarchy.items():
        if uri.startswith('http://data.europa.eu/esco/skill/'):
            top_level_categories.append({
                'uri': uri,
                'name': data['term'],
                'description': data['description']
            })
    
    # Create the taxonomy structure
    taxonomy = {
        'metadata': {
            'title': 'Military Skills Taxonomy',
            'description': 'A taxonomy mapping Air Force Specialty Codes (AFSCs) to relevant skills',
            'creationDate': datetime.now().isoformat(),
            'sources': ['ESCO', 'O*NET Military Crosswalk', 'ESCO-O*NET Crosswalk'],
            'totalAfscs': len(afsc_skill_mappings),
            'afscCategories': list(afscs_by_category.keys()),
            'topSkillCategories': top_level_categories,
        },
        'afscCategories': [
            {
                'categoryName': category,
                'afscs': afscs
            }
            for category, afscs in afscs_by_category.items()
        ],
        'skillHierarchy': {
            'topLevelCategories': top_level_categories,
            'structureDescription': 'Skills are organized in a 4-level hierarchy from broadest (Level 0) to most specific (Level 3)'
        }
    }
    
    return taxonomy

def main():
    """Main execution function"""
    try:
        logger.info("Starting Military Skills Taxonomy creation process")
        
        # Process Military Crosswalk to extract AFSCs
        afscs = process_military_crosswalk()
        
        # Save processed AFSC data
        with open(PROCESSED_AFSC_FILE, 'w', encoding='utf-8') as f:
            json.dump({
                'processedAfscs': afscs,
                'metadata': {
                    'count': len(afscs),
                    'processingDate': datetime.now().isoformat()
                }
            }, f, indent=2)
        logger.info(f"Saved processed AFSC data to {PROCESSED_AFSC_FILE}")
        
        # Process ESCO skills data
        esco_data = process_esco_skills()
        
        # Process ESCO-O*NET crosswalk
        crosswalk_data = process_esco_onet_crosswalk()
        
        # Save processed skills data
        with open(PROCESSED_SKILLS_FILE, 'w', encoding='utf-8') as f:
            json.dump({
                'processedEscoData': esco_data,
                'crosswalkData': crosswalk_data,
                'metadata': {
                    'skillCount': len(esco_data['skills']),
                    'processingDate': datetime.now().isoformat()
                }
            }, f, indent=2)
        logger.info(f"Saved processed ESCO skills data to {PROCESSED_SKILLS_FILE}")
        
        # Create AFSC to skill mappings
        afsc_skill_mappings = create_afsc_skill_mapping(afscs, esco_data, crosswalk_data)
        
        # Create taxonomy data
        taxonomy = create_taxonomy_data(afsc_skill_mappings, esco_data)
        
        # Save the merged taxonomy
        with open(MERGED_TAXONOMY_FILE, 'w', encoding='utf-8') as f:
            json.dump(taxonomy, f, indent=2)
        logger.info(f"Saved merged taxonomy to {MERGED_TAXONOMY_FILE}")
        
        logger.info("Military Skills Taxonomy creation process completed successfully")
        
    except Exception as e:
        logger.error(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# 2025-03-30 21:38:47,880 - INFO - Starting Military Skills Taxonomy creation process
# 2025-03-30 21:38:47,882 - INFO - Processing Military Crosswalk from: C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\milx0724.csv
# 2025-03-30 21:38:48,006 - INFO - Service counts in crosswalk: {'V': 4419, 'N': 7302, 'J': 809, 'C': 320, 'G': 1150, 'F': 9624, 'H': 4517, 'Y': 3418, 'U': 2377, 'A': 2086, 'X': 70, 'M': 2245, 'O': 20, 'S': 562, 'P': 208, 'D': 467, 'Q': 54, 'Z': 40, 'K': 343, 'L': 46}
# 2025-03-30 21:38:48,009 - INFO - Found 9624 Air Force entries
# 2025-03-30 21:38:48,057 - INFO - Processed 4020 active Air Force specialties
# 2025-03-30 21:38:48,124 - INFO - Saved processed AFSC data to C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\processed_afsc_data.json
# 2025-03-30 21:38:48,124 - INFO - Processing ESCO skills from: C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\skills_en.csv
# 2025-03-30 21:38:48,125 - INFO - Processing ESCO hierarchy from: C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\skillsHierarchy_en.csv
# 2025-03-30 21:38:48,251 - INFO - Processed 13939 ESCO skills
# 2025-03-30 21:38:48,252 - INFO - Skill types: skill/competence, knowledge,
# 2025-03-30 21:38:48,256 - INFO - Processed hierarchy with counts: {'level0': 4, 'level1': 28, 'level2': 156, 'level3': 452}
# 2025-03-30 21:38:48,542 - INFO - Processed 13492 skill-to-occupation mappings
# 2025-03-30 21:38:48,542 - INFO - Processed 3039 occupation-to-skill mappings
# 2025-03-30 21:38:48,542 - INFO - Processing ESCO to O*NET crosswalk from: C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\Original Crosswalk ESCO and ONet.csv
# 2025-03-30 21:38:48,557 - INFO - ESCO-O*NET crosswalk columns: Mapping project name, ESCO-O*NET Crosswalk, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6
# 2025-03-30 21:38:48,558 - WARNING - Could not identify ESCO and O*NET columns in the crosswalk file
# 2025-03-30 21:38:49,656 - INFO - Saved processed ESCO skills data to C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\processed_skills_data.json
# 2025-03-30 21:38:49,657 - INFO - Creating AFSC to ESCO skill mappings
# 2025-03-30 21:38:49,659 - INFO - Processing AFSC 2A512E: Helicopter/Tiltrotor Aircraft Maintenance Helper, MHU-139
# 2025-03-30 21:38:49,730 - INFO - Processing AFSC 2A532E: Helicopter/Tiltrotor Aircraft Maintenance Apprentice, MHU-139
# 2025-03-30 21:38:49,796 - INFO - Processing AFSC 2A552E: Helicopter/Tiltrotor Aircraft Maintenance Journeyman, MHU-139
# 2025-03-30 21:38:49,864 - INFO - Processing AFSC 4A051S: Health Services Management Journeyman, Health Information Technology
# 2025-03-30 21:38:49,933 - INFO - Processing AFSC 4A071S: Health Services Management Craftsman, Health Information Technology
# 2025-03-30 21:38:50,002 - INFO - Processing AFSC 8R300A: Third Tier Recruiter, Flight Chief
# 2025-03-30 21:38:50,067 - INFO - Processing AFSC 8R300B: Third Tier Recruiter, Graduated, Flight Chief
# 2025-03-30 21:38:50,133 - INFO - Processing AFSC 8R300C: Third Tier Recruiter, Production Superintendent
# 2025-03-30 21:38:50,197 - INFO - Processing AFSC 8R300E: Third Tier Recruiter, Senior Enlisted Leader
# 2025-03-30 21:38:50,266 - INFO - Processing AFSC 88I0: Innovation Officer
# 2025-03-30 21:38:50,320 - INFO - Processing AFSC 13A1: Astronaut
# 2025-03-30 21:38:50,380 - INFO - Processing AFSC 1A351A: Airborne Mission Systems Specialist Journeyman, C-32 / C-40
# 2025-03-30 21:38:50,446 - INFO - Processing AFSC 1A351D: Airborne Mission Systems Specialist Journeyman, C-37
# 2025-03-30 21:38:50,509 - INFO - Processing AFSC 1A351G: Airborne Mission Systems Specialist Journeyman, HC-130P/N
# 2025-03-30 21:38:50,572 - INFO - Processing AFSC 1A351H: Airborne Mission Systems Specialist Journeyman, EC-130J
# 2025-03-30 21:38:50,635 - INFO - Processing AFSC 1A351I: Airborne Mission Systems Specialist Journeyman, E-3
# 2025-03-30 21:38:50,694 - INFO - Processing AFSC 1A351J: Airborne Mission Systems Specialist Journeyman, E-4
# 2025-03-30 21:38:50,753 - INFO - Processing AFSC 1A351K: Airborne Mission Systems Specialist Journeyman, E-8
# 2025-03-30 21:38:50,813 - INFO - Processing AFSC 1A351L: Airborne Mission Systems Specialist Journeyman, EC-130H
# 2025-03-30 21:38:50,879 - INFO - Processing AFSC 1A351N: Airborne Mission Systems Specialist Journeyman, RC-135
# 2025-03-30 21:38:50,941 - INFO - Processing AFSC 1A351O: Airborne Mission Systems Specialist Journeyman, RQ-4
# 2025-03-30 21:38:51,004 - INFO - Processing AFSC 1A351T: Airborne Mission Systems Specialist Journeyman, MC-130P
# 2025-03-30 21:38:51,067 - INFO - Processing AFSC 1A371A: Airborne Mission Systems Specialist Craftsman, C-32 / C-40
# 2025-03-30 21:38:51,130 - INFO - Processing AFSC 1A371D: Airborne Mission Systems Specialist Craftsman, C-37
# 2025-03-30 21:38:51,192 - INFO - Processing AFSC 1A371G: Airborne Mission Systems Specialist Craftsman, HC-130P/N
# 2025-03-30 21:38:51,255 - INFO - Processing AFSC 1A371H: Airborne Mission Systems Specialist Craftsman, EC-130J
# 2025-03-30 21:38:51,318 - INFO - Processing AFSC 1A371I: Airborne Mission Systems Specialist Craftsman, E-3
# 2025-03-30 21:38:51,380 - INFO - Processing AFSC 1A371J: Airborne Mission Systems Specialist Craftsman, E-4
# 2025-03-30 21:38:51,440 - INFO - Processing AFSC 1A371K: Airborne Mission Systems Specialist Craftsman, E-8
# 2025-03-30 21:38:51,501 - INFO - Processing AFSC 1A371L: Airborne Mission Systems Specialist Craftsman, EC-130H
# 2025-03-30 21:38:51,565 - INFO - Processing AFSC 1A371N: Airborne Mission Systems Specialist Craftsman, RC-135
# 2025-03-30 21:38:51,629 - INFO - Processing AFSC 1A371O: Airborne Mission Systems Specialist Craftsman, RQ-4
# 2025-03-30 21:38:51,692 - INFO - Processing AFSC 1A371T: Airborne Mission Systems Specialist Craftsman, MC-130P
# 2025-03-30 21:38:51,754 - INFO - Processing AFSC 1N811: Targeting Analyst Helper
# 2025-03-30 21:38:51,815 - INFO - Processing AFSC 1N831: Targeting Analyst Apprentice
# 2025-03-30 21:38:51,872 - INFO - Processing AFSC 1N851: Targeting Analyst Journeyman, Targeteer
# 2025-03-30 21:38:51,936 - INFO - Processing AFSC 1N871: Targeting Analyst Craftsman, Targeteer
# 2025-03-30 21:38:51,999 - INFO - Processing AFSC 1U051O: Sensor Operator Journeyman, RQ-4
# 2025-03-30 21:38:52,070 - INFO - Processing AFSC 1U071O: Sensor Operator Craftsman, RQ-4
# 2025-03-30 21:38:52,141 - INFO - Processing AFSC 1U091O: Sensor Operator Superintendent, RQ-4
# 2025-03-30 21:38:52,212 - INFO - Processing AFSC 1U051Q: Sensor Operator Journeyman, MQ-1
# 2025-03-30 21:38:52,282 - INFO - Processing AFSC 1U071Q: Sensor Operator Craftsman, MQ-1
# 2025-03-30 21:38:52,350 - INFO - Processing AFSC 1U091Q: Sensor Operator Superintendent, MQ-1
# 2025-03-30 21:38:52,421 - INFO - Processing AFSC 1U051R: Sensor Operator Journeyman, MQ-9
# 2025-03-30 21:38:52,489 - INFO - Processing AFSC 1U071R: Sensor Operator Craftsman, MQ-9
# 2025-03-30 21:38:52,558 - INFO - Processing AFSC 1U091R: Sensor Operator Superintendent, MQ-9
# 2025-03-30 21:38:52,627 - INFO - Processing AFSC 1U051T: Sensor Operator Journeyman, MC-12
# 2025-03-30 21:38:52,696 - INFO - Processing AFSC 1U071T: Sensor Operator Craftsman, MC-12
# 2025-03-30 21:38:52,767 - INFO - Processing AFSC 1U091T: Sensor Operator Superintendent, MC-12
# 2025-03-30 21:38:52,836 - INFO - Processing AFSC 1U051U: Sensor Operator Journeyman, AC-130U
# 2025-03-30 21:38:52,909 - INFO - Processing AFSC 1U071U: Sensor Operator Craftsman, AC-130U
# 2025-03-30 21:38:52,989 - INFO - Processing AFSC 1U091U: Sensor Operator Superintendent, AC-130U
# 2025-03-30 21:38:53,059 - INFO - Processing AFSC 1U051V: Sensor Operator Journeyman, AC-130J
# 2025-03-30 21:38:53,129 - INFO - Processing AFSC 1U071V: Sensor Operator Craftsman, AC-130J
# 2025-03-30 21:38:53,199 - INFO - Processing AFSC 1U091V: Sensor Operator Superintendent, AC-130J
# 2025-03-30 21:38:53,270 - INFO - Processing AFSC 1U051W: Sensor Operator Journeyman, AC-130W
# 2025-03-30 21:38:53,340 - INFO - Processing AFSC 1U071W: Sensor Operator Craftsman, AC-130W
# 2025-03-30 21:38:53,413 - INFO - Processing AFSC 1U091W: Sensor Operator Superintendent, AC-130W
# 2025-03-30 21:38:53,482 - INFO - Processing AFSC 1U151O: Remotely Piloted Aircraft (RPA) Pilot Journeyman, RQ-4
# 2025-03-30 21:38:53,562 - INFO - Processing AFSC 1U171O: Remotely Piloted Aircraft (RPA) Pilot Craftsman, RQ-4
# 2025-03-30 21:38:53,638 - INFO - Processing AFSC 1U151R: Remotely Piloted Aircraft (RPA) Pilot Journeyman, MQ-9
# 2025-03-30 21:38:53,716 - INFO - Processing AFSC 1U171R: Remotely Piloted Aircraft (RPA) Pilot Craftsman, MQ-9
# 2025-03-30 21:38:53,793 - INFO - Processing AFSC 9H000: Academic Faculty Instructor
# 2025-03-30 21:38:53,851 - INFO - Processing AFSC 42P1E: Clinical Psychologist, Operational Psychologist
# 2025-03-30 21:38:53,916 - INFO - Processing AFSC 42P3E: Clinical Psychologist, Operational Psychologist
# 2025-03-30 21:38:53,976 - INFO - Processing AFSC 42P4E: Clinical Psychologist, Operational Psychologist
# 2025-03-30 21:38:54,036 - INFO - Processing AFSC 13A3: Astronaut
# 2025-03-30 21:38:54,093 - INFO - Processing AFSC 13A4: Astronaut
# 2025-03-30 21:38:54,151 - INFO - Processing AFSC 16K1D: Software Development Officer, Product Designer
# 2025-03-30 21:38:54,220 - INFO - Processing AFSC 16K1E: Software Development Officer, Software Engineer
# 2025-03-30 21:38:54,281 - INFO - Processing AFSC 16K1M: Software Development Officer, Product Manager
# 2025-03-30 21:38:54,350 - INFO - Processing AFSC 16K1S: Software Development Officer, Data Scientist
# 2025-03-30 21:38:54,414 - INFO - Processing AFSC 16K3D: Software Development Officer, Product Designer
# 2025-03-30 21:38:54,483 - INFO - Processing AFSC 16K3E: Software Development Officer, Software Engineer
# 2025-03-30 21:38:54,543 - INFO - Processing AFSC 16K3M: Software Development Officer, Product Manager
# 2025-03-30 21:38:54,610 - INFO - Processing AFSC 16K3S: Software Development Officer, Data Scientist
# 2025-03-30 21:38:54,670 - INFO - Processing AFSC 16K4D: Software Development Officer, Product Designer
# 2025-03-30 21:38:54,738 - INFO - Processing AFSC 16K4E: Software Development Officer, Software Engineer
# 2025-03-30 21:38:54,800 - INFO - Processing AFSC 16K4M: Software Development Officer, Product Manager
# 2025-03-30 21:38:54,869 - INFO - Processing AFSC 16K4S: Software Development Officer, Data Scientist
# 2025-03-30 21:38:54,931 - INFO - Processing AFSC 48R1E: Residency Trained Flight Surgeon, Board eligible in emergency medicine
# 2025-03-30 21:38:55,004 - INFO - Processing AFSC 48R3E: Residency Trained Flight Surgeon, Board eligible in emergency medicine
# 2025-03-30 21:38:55,078 - INFO - Processing AFSC 48R4E: Residency Trained Flight Surgeon, Board eligible in emergency medicine
# 2025-03-30 21:38:55,151 - INFO - Processing AFSC 48R1F: Residency Trained Flight Surgeon, Board eligible in family medicine
# 2025-03-30 21:38:55,225 - INFO - Processing AFSC 48R3F: Residency Trained Flight Surgeon, Board eligible in family medicine
# 2025-03-30 21:38:55,296 - INFO - Processing AFSC 48R4F: Residency Trained Flight Surgeon, Board eligible in family medicine
# 2025-03-30 21:38:55,369 - INFO - Processing AFSC 48R1M: Residency Trained Flight Surgeon, Board eligible in internal medicine
# 2025-03-30 21:38:55,445 - INFO - Processing AFSC 48R3M: Residency Trained Flight Surgeon, Board eligible in internal medicine
# 2025-03-30 21:38:55,520 - INFO - Processing AFSC 48R4M: Residency Trained Flight Surgeon, Board eligible in internal medicine
# 2025-03-30 21:38:55,595 - INFO - Processing AFSC 1D711: Cyber Defense Operations Helper
# 2025-03-30 21:38:55,659 - INFO - Processing AFSC 1D731: Cyber Defense Operations Apprentice
# 2025-03-30 21:38:55,722 - INFO - Processing AFSC 1D731A: Cyber Defense Operations Apprentice, Networks Operations
# 2025-03-30 21:38:55,792 - INFO - Processing AFSC 1D731B: Cyber Defense Operations Apprentice, Systems Operations
# 2025-03-30 21:38:55,861 - INFO - Processing AFSC 1D751: Cyber Defense Operations Journeyman
# 2025-03-30 21:38:55,926 - INFO - Processing AFSC 1D771: Cyber Defense Operations Craftsman
# 2025-03-30 21:38:55,989 - INFO - Processing AFSC 1Z400: Special Reconnaissance Chief Enlisted Manager
# 2025-03-30 21:38:56,052 - INFO - Processing AFSC 1Z411: Special Reconnaissance Helper
# 2025-03-30 21:38:56,109 - INFO - Processing AFSC 1Z431: Special Reconnaissance Apprentice
# 2025-03-30 21:38:56,162 - INFO - Processing AFSC 1Z451: Special Reconnaissance Journeyman
# 2025-03-30 21:38:56,222 - INFO - Processing AFSC 1Z471: Special Reconnaissance Craftsman
# 2025-03-30 21:38:56,274 - INFO - Processing AFSC 1Z491: Special Reconnaissance Superintendent
# 2025-03-30 21:38:56,327 - INFO - Processing AFSC 17D1Y: Warfighter Communications Operations, General
# 2025-03-30 21:38:56,393 - INFO - Processing AFSC 2A671C: Aerospace Propulsion Craftsman, TF33, CF6, F103, F108, F117, TFE-731, TF39, PW 2040, F138 Jet Engines (Airlift, Special Mission, and B-52 aircraft)
# 2025-03-30 21:38:56,500 - INFO - Processing AFSC 2A671F: Aerospace Propulsion Craftsman, F100, F101, F110, F118, F119, F135, TF34 Jet Engines (A-10, B-1, B-2, F-15, F-16, F-22, F-35, U-2 aircraft)
# 2025-03-30 21:38:56,600 - INFO - Processing AFSC 4N011C: Aerospace Medical Service Helper, Independent Duty Medical Technician
# 2025-03-30 21:38:56,677 - INFO - Processing AFSC 4N011F: Aerospace Medical Service Helper, Flight and Operational Medical Technician
# 2025-03-30 21:38:56,755 - INFO - Processing AFSC 4N031C: Aerospace Medical Service Apprentice, Independent Duty Medical Technician
# 2025-03-30 21:38:56,833 - INFO - Processing AFSC 4N031F: Aerospace Medical Service Apprentice, Flight and Operational Medical Technician
# 2025-03-30 21:38:56,913 - INFO - Processing AFSC 8K000: Software Development Specialist
# 2025-03-30 21:38:56,965 - INFO - Processing AFSC 9I000: Futures Airmen
# 2025-03-30 21:38:57,017 - INFO - Processing AFSC 1A331A: Airborne Mission Systems Specialist Apprentice, C-32 / C-40
# 2025-03-30 21:38:57,082 - INFO - Processing AFSC 1A331D: Airborne Mission Systems Specialist Apprentice, C-37
# 2025-03-30 21:38:57,146 - INFO - Processing AFSC 1A331G: Airborne Mission Systems Specialist Apprentice, HC-130P/N
# 2025-03-30 21:38:57,209 - INFO - Processing AFSC 1A331H: Airborne Mission Systems Specialist Apprentice, EC-130J
# 2025-03-30 21:38:57,275 - INFO - Processing AFSC 1A331I: Airborne Mission Systems Specialist Apprentice, E-3
# 2025-03-30 21:38:57,338 - INFO - Processing AFSC 1A331J: Airborne Mission Systems Specialist Apprentice, E-4
# 2025-03-30 21:38:57,400 - INFO - Processing AFSC 1A331K: Airborne Mission Systems Specialist Apprentice, E-8
# 2025-03-30 21:38:57,462 - INFO - Processing AFSC 1A331L: Airborne Mission Systems Specialist Apprentice, EC-130H
# 2025-03-30 21:38:57,525 - INFO - Processing AFSC 1A331N: Airborne Mission Systems Specialist Apprentice, RC-135
# 2025-03-30 21:38:57,590 - INFO - Processing AFSC 1A331O: Airborne Mission Systems Specialist Apprentice, RQ-4
# 2025-03-30 21:38:57,652 - INFO - Processing AFSC 1A331T: Airborne Mission Systems Specialist Apprentice, MC-130P
# 2025-03-30 21:38:57,714 - INFO - Processing AFSC 1U031O: Sensor Operator Apprentice, RQ-4
# 2025-03-30 21:38:57,788 - INFO - Processing AFSC 1U031Q: Sensor Operator Apprentice, MQ-1
# 2025-03-30 21:38:57,857 - INFO - Processing AFSC 1U031R: Sensor Operator Apprentice, MQ-9
# 2025-03-30 21:38:57,927 - INFO - Processing AFSC 1U031T: Sensor OperatorApprentice, MC-12
# 2025-03-30 21:38:57,996 - INFO - Processing AFSC 1U031U: Sensor Operator Apprentice, AC-130U
# 2025-03-30 21:38:58,068 - INFO - Processing AFSC 1U031V: Sensor Operator Apprentice, AC-130J
# 2025-03-30 21:38:58,138 - INFO - Processing AFSC 1U031W: Sensor Operator Apprentice, AC-130W
# 2025-03-30 21:38:58,209 - INFO - Processing AFSC 1U131O: Remotely Piloted Aircraft (RPA) Pilot Apprentice, RQ-4
# 2025-03-30 21:38:58,289 - INFO - Processing AFSC 1U131R: Remotely Piloted Aircraft (RPA) Pilot Apprentice, MQ-9
# 2025-03-30 21:38:58,367 - INFO - Processing AFSC 1Z100: Pararescue Manager
# 2025-03-30 21:38:58,420 - INFO - Processing AFSC 1Z111: Pararescue Helper
# 2025-03-30 21:38:58,474 - INFO - Processing AFSC 1Z131: Pararescue Apprentice
# 2025-03-30 21:38:58,525 - INFO - Processing AFSC 1Z151: Pararescue Journeyman
# 2025-03-30 21:38:58,580 - INFO - Processing AFSC 1Z171: Pararescue Craftsman
# 2025-03-30 21:38:58,633 - INFO - Processing AFSC 1Z191: Pararescue Superintendent
# 2025-03-30 21:38:58,685 - INFO - Processing AFSC 1Z200: Combat Control Manager
# 2025-03-30 21:38:58,752 - INFO - Processing AFSC 1Z211: Combat Control Helper
# 2025-03-30 21:38:58,811 - INFO - Processing AFSC 1Z231: Combat Control Apprentice
# 2025-03-30 21:38:58,871 - INFO - Processing AFSC 1Z251: Combat Control Journeyman
# 2025-03-30 21:38:58,931 - INFO - Processing AFSC 1Z271: Combat Control Craftsman
# 2025-03-30 21:38:58,995 - INFO - Processing AFSC 1Z291: Combat Control Superintendent
# 2025-03-30 21:38:59,064 - INFO - Processing AFSC 1Z300: Tactical Air Control Party (TACP) Manager
# 2025-03-30 21:38:59,134 - INFO - Processing AFSC 1Z311: Tactical Air Control Party (TACP) Helper
# 2025-03-30 21:38:59,199 - INFO - Processing AFSC 1Z331: Tactical Air Control Party (TACP) Apprentice
# 2025-03-30 21:38:59,267 - INFO - Processing AFSC 1Z351: Tactical Air Control Party (TACP) Journeyman
# 2025-03-30 21:38:59,334 - INFO - Processing AFSC 1Z371: Tactical Air Control Party (TACP) Craftsman
# 2025-03-30 21:38:59,402 - INFO - Processing AFSC 1Z391: Tactical Air Control Party (TACP) Superintendent
# 2025-03-30 21:38:59,493 - INFO - Processing AFSC 8L100: Enlisted Air Advisor - Basic
# 2025-03-30 21:38:59,539 - INFO - Processing AFSC 8L200: Enlisted Air Advisor - Basic, Team Sergeant
# 2025-03-30 21:38:59,594 - INFO - Processing AFSC 8L300: Enlisted Air Advisor - Basic, Team Leader
# 2025-03-30 21:38:59,648 - INFO - Processing AFSC 8L400: Enlisted Air Advisor - Advanced
# 2025-03-30 21:38:59,695 - INFO - Processing AFSC 8L500: Enlisted Air Advisor - Advanced, Team Sergeant
# 2025-03-30 21:38:59,750 - INFO - Processing AFSC 8L600: Enlisted Air Advisor - Advanced, Team Leader
# 2025-03-30 21:38:59,804 - INFO - Processing AFSC 8L700: Enlisted Combat Aviation Advisor (SOF)
# 2025-03-30 21:38:59,859 - INFO - Processing AFSC 8L800: Enlisted Combat Aviation Advisor (SOF), Team Sergeant
# 2025-03-30 21:38:59,919 - INFO - Processing AFSC 8L900: Enlisted Combat Aviation Advisor (SOF), Team Leader
# 2025-03-30 21:38:59,976 - INFO - Processing AFSC 9E200: Individual Mobilization Augmentee to Command Chief Master Sergeant
# 2025-03-30 21:39:00,049 - INFO - Processing AFSC 9Z000: Special Warfare Mission Support (SWMS) Career Field Manager (CFM) on Headquarters Air Force Staff, Air Force Special Warfare Division
# 2025-03-30 21:39:00,140 - INFO - Processing AFSC 9Z100: Special Warfare Mission Support (SWMS) Senior Enlisted Leader, Air Force Special Warfare (AFSPECWAR)
# 2025-03-30 21:39:00,226 - INFO - Processing AFSC 9Z200: Special Warfare Mission Support (SWMS) Superintendent, Air Force Special Warfare (AFSPECWAR)
# 2025-03-30 21:39:00,306 - INFO - Processing AFSC 46Y1F: Advanced Practice Registered Nurse (APRN), Aeromedical Nurse Practitioner
# 2025-03-30 21:39:00,375 - INFO - Processing AFSC 46Y3F: Advanced Practice Registered Nurse (APRN), Aeromedical Nurse Practitioner
# 2025-03-30 21:39:00,444 - INFO - Processing AFSC 46Y4F: Advanced Practice Registered Nurse (APRN), Aeromedical Nurse Practitioner
# 2025-03-30 21:39:00,515 - INFO - Processing AFSC 88B0: Protocol Officer
# 2025-03-30 21:39:00,570 - INFO - Processing AFSC 89A0: Officer Air Advisor (Conventional Force) Basic
# 2025-03-30 21:39:00,636 - INFO - Processing AFSC 89B0: Officer Air Advisor (Conventional Force) Basic, Team Leader
# 2025-03-30 21:39:00,708 - INFO - Processing AFSC 89C0: Officer Air Advisor (Conventional Force) Basic, Mission Commander
# 2025-03-30 21:39:00,780 - INFO - Processing AFSC 89D0: Officer Air Advisor (Conventional Force) Advanced
# 2025-03-30 21:39:00,847 - INFO - Processing AFSC 89E0: Officer Air Advisor (Conventional Force) Advanced, Team Leader
# 2025-03-30 21:39:00,918 - INFO - Processing AFSC 89F0: Officer Air Advisor (Conventional Force) Advanced, Mission Commander
# 2025-03-30 21:39:00,991 - INFO - Processing AFSC 89G0: Officer Combat Aviation Advisor
# 2025-03-30 21:39:01,053 - INFO - Processing AFSC 89H0: Officer Combat Aviation Advisor, Team Leader
# 2025-03-30 21:39:01,122 - INFO - Processing AFSC 89I0: Officer Combat Aviation Advisor, Mission Commander
# 2025-03-30 21:39:01,190 - INFO - Processing AFSC 3N251: Premier Band  - The USAF Band Journeyman
# 2025-03-30 21:39:01,264 - INFO - Processing AFSC 3N300: Premier Band  - The USAF Academy Band Manager
# 2025-03-30 21:39:01,325 - INFO - Processing AFSC 3N351: Premier Band  - The USAF Academy Band Journeyman
# 2025-03-30 21:39:01,386 - INFO - Processing AFSC 3N371: Premier Band  - The USAF Academy Band Craftsman
# 2025-03-30 21:39:01,448 - INFO - Processing AFSC 3N391: Premier Band  - The USAF Academy Band Superintendent
# 2025-03-30 21:39:01,514 - INFO - Processing AFSC 4N011D: Aerospace Medical Service Helper, Allergy/Immunization Technician
# 2025-03-30 21:39:01,579 - INFO - Processing AFSC 4N031D: Aerospace Medical Service Apprentice, Allergy/Immunization Technician
# 2025-03-30 21:39:01,644 - INFO - Processing AFSC 4N051D: Aerospace Medical Service Journeyman, Allergy/Immunization Technician
# 2025-03-30 21:39:01,709 - INFO - Processing AFSC 4N071D: Aerospace Medical Service Craftsman, Allergy/Immunization Technician
# 2025-03-30 21:39:01,776 - INFO - Processing AFSC 8S200: Combat Crew Communications
# 2025-03-30 21:39:01,847 - INFO - Processing AFSC 9S000: Chief Master Sergeant of the Space Force
# 2025-03-30 21:39:01,904 - INFO - Processing AFSC 9T500: Basic Special Warfare Enlisted Airman
# 2025-03-30 21:39:01,959 - INFO - Processing AFSC 9Q000: Reserve Force Generation and Oversight NCO
# 2025-03-30 21:39:02,011 - INFO - Processing AFSC 15A1: Operations Analysis Officer
# 2025-03-30 21:39:02,069 - INFO - Processing AFSC 15A1M: Operations Analysis Officer, RPA
# 2025-03-30 21:39:02,128 - INFO - Processing AFSC 15A1N: Operations Analysis Officer, ABM
# 2025-03-30 21:39:02,188 - INFO - Processing AFSC 15A1P: Operations Analysis Officer, Fighter
# 2025-03-30 21:39:02,251 - INFO - Processing AFSC 15A1Q: Operations Analysis Officer, Trainer
# 2025-03-30 21:39:02,315 - INFO - Processing AFSC 15A1R: Operations Analysis Officer, Bomber
# 2025-03-30 21:39:02,378 - INFO - Processing AFSC 15A1S: Operations Analysis Officer, Tanker
# 2025-03-30 21:39:02,440 - INFO - Processing AFSC 15A1T: Operations Analysis Officer, Airlift
# 2025-03-30 21:39:02,504 - INFO - Processing AFSC 15A1V: Operations Analysis Officer, Helicopter or EWO
# 2025-03-30 21:39:02,565 - INFO - Processing AFSC 15A1W: Operations Analysis Officer, General
# 2025-03-30 21:39:02,627 - INFO - Processing AFSC 15A1Y: Operations Analysis Officer, Special Operations
# 2025-03-30 21:39:02,689 - INFO - Processing AFSC 15A1Z: Operations Analysis Officer, C2ISREW
# 2025-03-30 21:39:02,750 - INFO - Processing AFSC 15A3: Operations Analysis Officer
# 2025-03-30 21:39:02,810 - INFO - Processing AFSC 15A3M: Operations Analysis Officer, RPA
# 2025-03-30 21:39:02,869 - INFO - Processing AFSC 15A3N: Operations Analysis Officer, ABM
# 2025-03-30 21:39:02,929 - INFO - Processing AFSC 15A3P: Operations Analysis Officer, Fighter
# 2025-03-30 21:39:02,990 - INFO - Processing AFSC 15A3Q: Operations Analysis Officer, Trainer
# 2025-03-30 21:39:03,052 - INFO - Processing AFSC 15A3R: Operations Analysis Officer, Bomber
# 2025-03-30 21:39:03,116 - INFO - Processing AFSC 15A3S: Operations Analysis Officer, Tanker
# 2025-03-30 21:39:03,177 - INFO - Processing AFSC 15A3T: Operations Analysis Officer, Airlift
# 2025-03-30 21:39:03,239 - INFO - Processing AFSC 15A3V: Operations Analysis Officer, Helicopter or EWO
# 2025-03-30 21:39:03,303 - INFO - Processing AFSC 15A3W: Operations Analysis Officer, General
# 2025-03-30 21:39:03,368 - INFO - Processing AFSC 15A3Y: Operations Analysis Officer, Special Operations
# 2025-03-30 21:39:03,434 - INFO - Processing AFSC 15A3Z: Operations Analysis Officer, C2ISREW
# 2025-03-30 21:39:03,497 - INFO - Processing AFSC 15A4: Operations Analysis Officer
# 2025-03-30 21:39:03,557 - INFO - Processing AFSC 15A4M: Operations Analysis Officer, RPA
# 2025-03-30 21:39:03,617 - INFO - Processing AFSC 15A4N: Operations Analysis Officer, ABM
# 2025-03-30 21:39:03,678 - INFO - Processing AFSC 15A4P: Operations Analysis Officer, Fighter
# 2025-03-30 21:39:03,739 - INFO - Processing AFSC 15A4Q: Operations Analysis Officer, Trainer
# 2025-03-30 21:39:03,801 - INFO - Processing AFSC 15A4R: Operations Analysis Officer, Bomber
# 2025-03-30 21:39:03,863 - INFO - Processing AFSC 15A4S: Operations Analysis Officer, Tanker
# 2025-03-30 21:39:03,924 - INFO - Processing AFSC 15A4T: Operations Analysis Officer, Airlift
# 2025-03-30 21:39:03,987 - INFO - Processing AFSC 15A4V: Operations Analysis Officer, Helicopter or EWO
# 2025-03-30 21:39:04,050 - INFO - Processing AFSC 15A4W: Operations Analysis Officer, General
# 2025-03-30 21:39:04,111 - INFO - Processing AFSC 15A4Y: Operations Analysis Officer, Special Operations
# 2025-03-30 21:39:04,175 - INFO - Processing AFSC 15A4Z: Operations Analysis Officer, C2ISREW
# 2025-03-30 21:39:04,237 - INFO - Processing AFSC 17S1Y: Cyberspace Effects Operations, Special Operations (if Prefix P)
# 2025-03-30 21:39:04,310 - INFO - Processing AFSC 17S1Z: Cyberspace Effects Operations , C2ISREW
# 2025-03-30 21:39:04,375 - INFO - Processing AFSC 17S1S: Cyberspace Effects Operations, Software Development
# 2025-03-30 21:39:04,444 - INFO - Processing AFSC 17S2S: Cyberspace Effects Operations, Software Development
# 2025-03-30 21:39:04,514 - INFO - Processing AFSC 17S3S: Cyberspace Effects Operations, Software Development
# 2025-03-30 21:39:04,583 - INFO - Processing AFSC 17S4S: Cyberspace Effects Operations, Software Development
# 2025-03-30 21:39:04,652 - INFO - Processing AFSC 17S2Y: Cyberspace Effects Operations, Special Operations (if Prefix P)
# 2025-03-30 21:39:04,726 - INFO - Processing AFSC 17S3Y: Cyberspace Effects Operations, Special Operations (if Prefix P)
# 2025-03-30 21:39:04,799 - INFO - Processing AFSC 17S4Y: Cyberspace Effects Operations, Special Operations (if Prefix P)
# 2025-03-30 21:39:04,884 - INFO - Processing AFSC 17S2Z: Cyberspace Effects Operations , C2ISREW (if Prefix P)
# 2025-03-30 21:39:04,953 - INFO - Processing AFSC 17S3Z: Cyberspace Effects Operations , C2ISREW (if Prefix P)
# 2025-03-30 21:39:05,023 - INFO - Processing AFSC 17S4Z: Cyberspace Effects Operations , C2ISREW (if Prefix N or P)
# 2025-03-30 21:39:05,093 - INFO - Processing AFSC 19Z1A: Special Warfare, Special Tactics Officer
# 2025-03-30 21:39:05,154 - INFO - Processing AFSC 19Z1B: Special Warfare, Tactical Air Control Party Officer
# 2025-03-30 21:39:05,219 - INFO - Processing AFSC 19Z1C: Special Warfare, Combat Rescue Officer
# 2025-03-30 21:39:05,281 - INFO - Processing AFSC 19Z2A: Special Warfare, Special Tactics Officer
# 2025-03-30 21:39:05,340 - INFO - Processing AFSC 19Z2B: Special Warfare, Tactical Air Control Party Officer
# 2025-03-30 21:39:05,404 - INFO - Processing AFSC 19Z2C: Special Warfare, Combat Rescue Officer
# 2025-03-30 21:39:05,465 - INFO - Processing AFSC 19Z3A: Special Warfare, Special Tactics Officer
# 2025-03-30 21:39:05,524 - INFO - Processing AFSC 19Z3B: Special Warfare, Tactical Air Control Party Officer
# 2025-03-30 21:39:05,589 - INFO - Processing AFSC 19Z3C: Special Warfare, Combat Rescue Officer
# 2025-03-30 21:39:05,653 - INFO - Processing AFSC 19Z4A: Special Warfare, Special Tactics Officer
# 2025-03-30 21:39:05,714 - INFO - Processing AFSC 19Z4B: Special Warfare, Tactical Air Control Party Officer
# 2025-03-30 21:39:05,777 - INFO - Processing AFSC 19Z4C: Special Warfare, Combat Rescue Officer
# 2025-03-30 21:39:05,841 - INFO - Processing AFSC 42G1N: Physician Assistant, Psychiatry
# 2025-03-30 21:39:05,895 - INFO - Processing AFSC 42G3N: Physician Assistant, Psychiatry
# 2025-03-30 21:39:05,947 - INFO - Processing AFSC 42G4N: Physician Assistant, Psychiatry
# 2025-03-30 21:39:06,000 - INFO - Processing AFSC 42G1P: Physician Assistant, Aeromedical
# 2025-03-30 21:39:06,053 - INFO - Processing AFSC 42G3P: Physician Assistant, Aeromedical
# 2025-03-30 21:39:06,108 - INFO - Processing AFSC 42G4P: Physician Assistant, Aeromedical
# 2025-03-30 21:39:06,161 - INFO - Processing AFSC 81D0: Air Force Reserve Officer Training Corps Detachment Commander and Professor of Aerospace Studies
# 2025-03-30 21:39:06,243 - INFO - Processing AFSC 81L0: Education and Training Leader
# 2025-03-30 21:39:06,299 - INFO - Processing AFSC 88C0: Sexual Assault Response Coordinator (SARC)
# 2025-03-30 21:39:06,371 - INFO - Processing AFSC 19Z1: Special Warfare
# 2025-03-30 21:39:06,424 - INFO - Processing AFSC 19Z2: Special Warfare
# 2025-03-30 21:39:06,475 - INFO - Processing AFSC 19Z3: Special Warfare
# 2025-03-30 21:39:06,531 - INFO - Processing AFSC 19Z4: Special Warfare
# 2025-03-30 21:39:06,584 - INFO - Processing AFSC 8U100: Weapons of Mass Destruction Civil Support Team (WMD-CST)
# 2025-03-30 21:39:06,640 - INFO - Processing AFSC 1D700: Cyber Defense Operations Manager
# 2025-03-30 21:39:06,704 - INFO - Processing AFSC 1D791: Cyber Defense Operations Superintendent
# 2025-03-30 21:39:06,768 - INFO - Processing AFSC 1D731R: Cyber Defense Operations Apprentice, RF Operations
# 2025-03-30 21:39:06,833 - INFO - Processing AFSC 1D731Z: Cyber Defense Operations Apprentice, Software Development Operations
# 2025-03-30 21:39:06,907 - INFO - Processing AFSC 1U031Y: Sensor Operator Apprentice, CAA
# 2025-03-30 21:39:06,979 - INFO - Processing AFSC 1U051Y: Sensor Operator Journeyman, CAA
# 2025-03-30 21:39:07,049 - INFO - Processing AFSC 1U071Y: Sensor Operator Craftsman, CAA
# 2025-03-30 21:39:07,119 - INFO - Processing AFSC 3N016: Public Affairs Helper
# 2025-03-30 21:39:07,177 - INFO - Processing AFSC 3N036: Public Affairs Apprentice
# 2025-03-30 21:39:07,234 - INFO - Processing AFSC 89W0: Weapons of Mass Destruction Civil Support Team (WMD-CST)
# 2025-03-30 21:39:07,305 - INFO - Processing AFSC 3N056: Public Affairs Journeyman
# 2025-03-30 21:39:07,364 - INFO - Processing AFSC 3N076: Public Affairs Craftsman
# 2025-03-30 21:39:07,422 - INFO - Processing AFSC 8I100: Inspections Coordinator
# 2025-03-30 21:39:07,475 - INFO - Processing AFSC 8I200: Complaints & Resolution Coordinator
# 2025-03-30 21:39:07,534 - INFO - Processing AFSC 13O1: Multi-Domain Warfare Officer
# 2025-03-30 21:39:07,596 - INFO - Processing AFSC 13O3: Multi-Domain Warfare Officer
# 2025-03-30 21:39:07,658 - INFO - Processing AFSC 13O4: Multi-Domain Warfare Officer
# 2025-03-30 21:39:07,719 - INFO - Processing AFSC 41A1A: Health Services Administrator, Health Facilities Architect/Engineer/Construction Manager
# 2025-03-30 21:39:07,791 - INFO - Processing AFSC 41A3A: Health Services Administrator, Health Facilities Architect/Engineer/Construction Manager
# 2025-03-30 21:39:07,865 - INFO - Processing AFSC 41A4A: Health Services Administrator, Health Facilities Architect/Engineer/Construction Manager
# 2025-03-30 21:39:07,939 - INFO - Processing AFSC 44F1C: Family Physician, Pain Management
# 2025-03-30 21:39:07,996 - INFO - Processing AFSC 44F3C: Family Physician, Pain Management
# 2025-03-30 21:39:08,054 - INFO - Processing AFSC 44F4C: Family Physician, Pain Management
# 2025-03-30 21:39:08,114 - INFO - Processing AFSC 44K1N: Pediatrician, Child Abuse
# 2025-03-30 21:39:08,173 - INFO - Processing AFSC 44K3N: Pediatrician, Child Abuse
# 2025-03-30 21:39:08,231 - INFO - Processing AFSC 44K4N: Pediatrician, Child Abuse
# 2025-03-30 21:39:08,289 - INFO - Processing AFSC 44K1P: Pediatrician, Sleep Medicine
# 2025-03-30 21:39:08,347 - INFO - Processing AFSC 44K3P: Pediatrician, Sleep Medicine
# 2025-03-30 21:39:08,403 - INFO - Processing AFSC 44K4P: Pediatrician, Sleep Medicine
# 2025-03-30 21:39:08,461 - INFO - Processing AFSC 44M1K: Internal Medicine Physician, Geriatrics/Palliative Care Medicine
# 2025-03-30 21:39:08,528 - INFO - Processing AFSC 44M3K: Internal Medicine Physician, Geriatrics/Palliative Care Medicine
# 2025-03-30 21:39:08,597 - INFO - Processing AFSC 44M4K: Internal Medicine Physician, Geriatrics/Palliative Care Medicine
# 2025-03-30 21:39:08,671 - INFO - Processing AFSC 44M1L: Internal Medicine Physician, Sleep Medicine
# 2025-03-30 21:39:08,733 - INFO - Processing AFSC 44M3L: Internal Medicine Physician, Sleep Medicine
# 2025-03-30 21:39:08,796 - INFO - Processing AFSC 44M4L: Internal Medicine Physician, Sleep Medicine
# 2025-03-30 21:39:08,858 - INFO - Processing AFSC 44N1A: Neurologist, Sleep Medicine
# 2025-03-30 21:39:08,912 - INFO - Processing AFSC 44N3A: Neurologist, Sleep Medicine
# 2025-03-30 21:39:08,966 - INFO - Processing AFSC 44N4A: Neurologist, Sleep Medicine
# 2025-03-30 21:39:09,017 - INFO - Processing AFSC 44R1G: Radiologist, Body Imaging
# 2025-03-30 21:39:09,067 - INFO - Processing AFSC 44R3G: Radiologist, Body Imaging
# 2025-03-30 21:39:09,116 - INFO - Processing AFSC 44R4G: Radiologist, Body Imaging
# 2025-03-30 21:39:09,167 - INFO - Processing AFSC 44R1H: Radiologist, Cardiothoracic Imaging
# 2025-03-30 21:39:09,221 - INFO - Processing AFSC 44R3H: Radiologist, Cardiothoracic Imaging
# 2025-03-30 21:39:09,272 - INFO - Processing AFSC 44R4H: Radiologist, Cardiothoracic Imaging
# 2025-03-30 21:39:09,323 - INFO - Processing AFSC 44R1J: Radiologist, Women’s Imaging
# 2025-03-30 21:39:09,387 - INFO - Processing AFSC 44R3J: Radiologist, Women’s Imaging
# 2025-03-30 21:39:09,450 - INFO - Processing AFSC 44R4J: Radiologist, Women’s Imaging
# 2025-03-30 21:39:09,515 - INFO - Processing AFSC 44S1C: Dermatologist, Pediatric Dermatology
# 2025-03-30 21:39:09,569 - INFO - Processing AFSC 44S3C: Dermatologist, Pediatric Dermatology
# 2025-03-30 21:39:09,621 - INFO - Processing AFSC 44S4C: Dermatologist, Pediatric Dermatology
# 2025-03-30 21:39:09,675 - INFO - Processing AFSC 45A1A: Anesthesiologist, Cardiothoracic
# 2025-03-30 21:39:09,730 - INFO - Processing AFSC 45A3A: Anesthesiologist, Cardiothoracic
# 2025-03-30 21:39:09,779 - INFO - Processing AFSC 45A4A: Anesthesiologist, Cardiothoracic
# 2025-03-30 21:39:09,830 - INFO - Processing AFSC 45A1B: Anesthesiologist, Pain Management
# 2025-03-30 21:39:09,884 - INFO - Processing AFSC 45A3B: Anesthesiologist, Pain Management
# 2025-03-30 21:39:09,937 - INFO - Processing AFSC 45A4B: Anesthesiologist, Pain Management
# 2025-03-30 21:39:09,991 - INFO - Processing AFSC 45G1F: Gynecologic Surgeon and Obstetrician, Minimally-Invasive Gynecologic Surgery (MIGS)
# 2025-03-30 21:39:10,062 - INFO - Processing AFSC 45G3F: Gynecologic Surgeon and Obstetrician, Minimally-Invasive Gynecologic Surgery (MIGS)
# 2025-03-30 21:39:10,128 - INFO - Processing AFSC 45G4F: Gynecologic Surgeon and Obstetrician, Minimally-Invasive Gynecologic Surgery (MIGS)
# 2025-03-30 21:39:10,196 - INFO - Processing AFSC 45N1E: Otorhinolaryngologist - Head and Neck Surgeon, Rhinology & Cranial Base Surgery
# 2025-03-30 21:39:10,265 - INFO - Processing AFSC 45N3E: Otorhinolaryngologist - Head and Neck Surgeon, Rhinology & Cranial Base Surgery
# 2025-03-30 21:39:10,332 - INFO - Processing AFSC 45N4E: Otorhinolaryngologist - Head and Neck Surgeon, Rhinology & Cranial Base Surgery
# 2025-03-30 21:39:10,401 - INFO - Processing AFSC 45N1F: Otorhinolaryngologist - Head and Neck Surgeon, Laryngology
# 2025-03-30 21:39:10,458 - INFO - Processing AFSC 45N3F: Otorhinolaryngologist - Head and Neck Surgeon, Laryngology
# 2025-03-30 21:39:10,518 - INFO - Processing AFSC 45N4F: Otorhinolaryngologist - Head and Neck Surgeon, Laryngology
# 2025-03-30 21:39:10,578 - INFO - Processing AFSC 45N1G: Otorhinolaryngologist - Head and Neck Surgeon, Sleep Surgeon
# 2025-03-30 21:39:10,639 - INFO - Processing AFSC 45N3G: Otorhinolaryngologist - Head and Neck Surgeon, Sleep Surgeon
# 2025-03-30 21:39:10,701 - INFO - Processing AFSC 45N4G: Otorhinolaryngologist - Head and Neck Surgeon, Sleep Surgeon
# 2025-03-30 21:39:10,762 - INFO - Processing AFSC 45U1D: Urologist, Endourology/Robotics
# 2025-03-30 21:39:10,811 - INFO - Processing AFSC 45U3D: Urologist, Endourology/Robotics
# 2025-03-30 21:39:10,863 - INFO - Processing AFSC 45U4D: Urologist, Endourology/Robotics
# 2025-03-30 21:39:10,914 - INFO - Processing AFSC 45U1E: Urologist, Female Urology/Reconstruction
# 2025-03-30 21:39:10,968 - INFO - Processing AFSC 45U3E: Urologist, Female Urology/Reconstruction
# 2025-03-30 21:39:11,024 - INFO - Processing AFSC 45U4E: Urologist, Female Urology/Reconstruction
# 2025-03-30 21:39:11,079 - INFO - Processing AFSC 1A100: Mobility Force Aviator Manager
# 2025-03-30 21:39:11,143 - INFO - Processing AFSC 1A300: Airborne Mission Systems Specialist Manager
# 2025-03-30 21:39:11,217 - INFO - Processing AFSC 1A311: Airborne Mission Systems Specialist Helper
# 2025-03-30 21:39:11,281 - INFO - Processing AFSC 1A331: Airborne Mission Systems Specialist Apprentice
# 2025-03-30 21:39:11,340 - INFO - Processing AFSC 1A351: Airborne Mission Systems Specialist Journeyman
# 2025-03-30 21:39:11,401 - INFO - Processing AFSC 1A371: Airborne Mission Systems Specialist Craftsman
# 2025-03-30 21:39:11,461 - INFO - Processing AFSC 1A391: Airborne Mission Systems Specialist Superintendent
# 2025-03-30 21:39:11,528 - INFO - Processing AFSC 1A800: SEL Airborne Intelligence, Surveillance and Reconnaissance (ISR) Manager
# 2025-03-30 21:39:11,603 - INFO - Processing AFSC 1A811: Airborne Cryptologic Language Analyst Helper
# 2025-03-30 21:39:11,668 - INFO - Processing AFSC 1A831: Airborne Cryptologic Language Analyst Apprentice
# 2025-03-30 21:39:11,732 - INFO - Processing AFSC 1A851: Airborne Cryptologic Language Analyst Journeyman
# 2025-03-30 21:39:11,795 - INFO - Processing AFSC 1A871: Airborne Cryptologic Language Analyst Craftsman
# 2025-03-30 21:39:11,857 - INFO - Processing AFSC 1C000: Aviation Resource Management Manager
# 2025-03-30 21:39:11,927 - INFO - Processing AFSC 1C012: Aviation Resource Management Helper
# 2025-03-30 21:39:11,990 - INFO - Processing AFSC 1C032: Aviation Resource Management Apprentice
# 2025-03-30 21:39:12,054 - INFO - Processing AFSC 1C052: Aviation Resource Management Journeyman
# 2025-03-30 21:39:12,118 - INFO - Processing AFSC 1C072: Aviation Resource Management Craftsman
# 2025-03-30 21:39:12,181 - INFO - Processing AFSC 1C092: Aviation Resource Management Superintendent
# 2025-03-30 21:39:12,252 - INFO - Processing AFSC 1C100: Air Traffic Control Manager
# 2025-03-30 21:39:12,309 - INFO - Processing AFSC 1C111: Air Traffic Control Helper
# 2025-03-30 21:39:12,373 - INFO - Processing AFSC 1C131: Air Traffic Control Apprentice
# 2025-03-30 21:39:12,428 - INFO - Processing AFSC 1C151: Air Traffic Control Journeyman
# 2025-03-30 21:39:12,479 - INFO - Processing AFSC 1C171: Air Traffic Control Craftsman
# 2025-03-30 21:39:12,533 - INFO - Processing AFSC 1C191: Air Traffic Control Superintendent
# 2025-03-30 21:39:12,587 - INFO - Processing AFSC 1C300: All-Domain Command and Control Operations Manager
# 2025-03-30 21:39:12,659 - INFO - Processing AFSC 1C311: All-Domain Command and Control Operations Helper
# 2025-03-30 21:39:12,724 - INFO - Processing AFSC 1C331: All-Domain Command and Control Operations Apprentice
# 2025-03-30 21:39:12,790 - INFO - Processing AFSC 1C351: All-Domain Command and Control Operations Journeyman
# 2025-03-30 21:39:12,857 - INFO - Processing AFSC 1C371: All-Domain Command and Control Operations Craftsman
# 2025-03-30 21:39:12,923 - INFO - Processing AFSC 1C391: All-Domain Command and Control Operations Superintendent
# 2025-03-30 21:39:12,996 - INFO - Processing AFSC 1C500: Battle Management Operations Manager
# 2025-03-30 21:39:13,064 - INFO - Processing AFSC 1C511: Battle Management Operations Helper
# 2025-03-30 21:39:13,132 - INFO - Processing AFSC 1C531: Battle Management Operations Apprentice
# 2025-03-30 21:39:13,197 - INFO - Processing AFSC 1C551: Battle Management Operations Journeyman
# 2025-03-30 21:39:13,262 - INFO - Processing AFSC 1C551D: Battle Management Operations Journeyman, Weapons Director
# 2025-03-30 21:39:13,333 - INFO - Processing AFSC 1C571: Battle Management Operations Craftsman
# 2025-03-30 21:39:13,398 - INFO - Processing AFSC 1C571D: Battle Management Operations Craftsman, Weapons Director
# 2025-03-30 21:39:13,470 - INFO - Processing AFSC 1C591: Battle Management Operations Superintendent
# 2025-03-30 21:39:13,539 - INFO - Processing AFSC 1C600: Space Systems Operations Manager
# 2025-03-30 21:39:13,606 - INFO - Processing AFSC 1C611: Space Systems Operations Helper
# 2025-03-30 21:39:13,677 - INFO - Processing AFSC 1C631: Space Systems Operations Apprentice
# 2025-03-30 21:39:13,744 - INFO - Processing AFSC 1C651: Space Systems Operations Journeyman
# 2025-03-30 21:39:13,812 - INFO - Processing AFSC 1C671: Space Systems Operations Craftsman
# 2025-03-30 21:39:13,879 - INFO - Processing AFSC 1C691: Space Systems Operations Superintendent
# 2025-03-30 21:39:13,947 - INFO - Processing AFSC 1C700: Airfield Management Manager
# 2025-03-30 21:39:14,013 - INFO - Processing AFSC 1C711: Airfield Management Helper
# 2025-03-30 21:39:14,074 - INFO - Processing AFSC 1C731: Airfield Management Apprentice
# 2025-03-30 21:39:14,132 - INFO - Processing AFSC 1C751: Airfield Management Journeyman
# 2025-03-30 21:39:14,190 - INFO - Processing AFSC 1C771: Airfield Management Craftsman
# 2025-03-30 21:39:14,248 - INFO - Processing AFSC 1C791: Airfield Management Superintendent
# 2025-03-30 21:39:14,315 - INFO - Processing AFSC 1N000: Intelligence Manager
# 2025-03-30 21:39:14,380 - INFO - Processing AFSC 1N011: All Source Intelligence Analyst Helper
# 2025-03-30 21:39:14,447 - INFO - Processing AFSC 1N031: All Source Intelligence Analyst Apprentice
# 2025-03-30 21:39:14,515 - INFO - Processing AFSC 1N051: All Source Intelligence Analyst Journeyman
# 2025-03-30 21:39:14,590 - INFO - Processing AFSC 1N071: All Source Intelligence Analyst Craftsman
# 2025-03-30 21:39:14,656 - INFO - Processing AFSC 1S000: Safety Manager
# 2025-03-30 21:39:14,711 - INFO - Processing AFSC 1S011: Safety Helper
# 2025-03-30 21:39:14,768 - INFO - Processing AFSC 1S031: Safety Apprentice
# 2025-03-30 21:39:14,824 - INFO - Processing AFSC 1S051: Safety Journeyman
# 2025-03-30 21:39:14,879 - INFO - Processing AFSC 1S071: Safety Craftsman
# 2025-03-30 21:39:14,933 - INFO - Processing AFSC 1S091: Safety Superintendent
# 2025-03-30 21:39:14,988 - INFO - Processing AFSC 1T000: Survival, Evasion, Resistance, Escape (SERE) Specialist Manager
# 2025-03-30 21:39:15,060 - INFO - Processing AFSC 1T011: Survival, Evasion, Resistance, Escape (SERE) Specialist Helper
# 2025-03-30 21:39:15,135 - INFO - Processing AFSC 1T031: Survival, Evasion, Resistance, Escape (SERE) Specialist Apprentice
# 2025-03-30 21:39:15,211 - INFO - Processing AFSC 1T051: Survival, Evasion, Resistance, Escape (SERE) Specialist Journeyman
# 2025-03-30 21:39:15,287 - INFO - Processing AFSC 1T071: Survival, Evasion, Resistance, Escape (SERE) Specialist Craftsman
# 2025-03-30 21:39:15,361 - INFO - Processing AFSC 1T091: Survival, Evasion, Resistance, Escape (SERE) Specialist Superintendent
# 2025-03-30 21:39:15,436 - INFO - Processing AFSC 1W000: Weather Manager
# 2025-03-30 21:39:15,498 - INFO - Processing AFSC 1W011: Weather Helper
# 2025-03-30 21:39:15,563 - INFO - Processing AFSC 1W031: Weather Apprentice
# 2025-03-30 21:39:15,627 - INFO - Processing AFSC 1W051: Weather Journeyman
# 2025-03-30 21:39:15,690 - INFO - Processing AFSC 1W091: Weather Superintendent
# 2025-03-30 21:39:15,747 - INFO - Processing AFSC 2A090: Avionics Superintendent
# 2025-03-30 21:39:15,816 - INFO - Processing AFSC 2A300: Fighter/Remotely Piloted Aircraft Maintenance Manager
# 2025-03-30 21:39:15,889 - INFO - Processing AFSC 2A313E: Tactical Aircraft Maintenance Helper, A-10/U-2
# 2025-03-30 21:39:15,955 - INFO - Processing AFSC 2A333E: Tactical Aircraft Maintenance Apprentice, A-10/U-2
# 2025-03-30 21:39:16,017 - INFO - Processing AFSC 2A373: Tactical Aircraft Maintenance Craftsman
# 2025-03-30 21:39:16,087 - INFO - Processing AFSC 2A390: Fighter/Remotely Piloted Aircraft Maintenance Superintendent
# 2025-03-30 21:39:16,163 - INFO - Processing AFSC 2A511A: Airlift/Special Mission Aircraft Maintenance Helper, C-20/C-21/C-22/C-37/C-40/E-4/VC-25
# 2025-03-30 21:39:16,238 - INFO - Processing AFSC 2A511B: Airlift/Special Mission Aircraft Maintenance Helper, C-130/C-27J
# 2025-03-30 21:39:16,309 - INFO - Processing AFSC 2A511C: Airlift/Special Mission Aircraft Maintenance Helper, C-5
# 2025-03-30 21:39:16,377 - INFO - Processing AFSC 2A511D: Airlift/Special Mission Aircraft Maintenance Helper, C-17
# 2025-03-30 21:39:16,449 - INFO - Processing AFSC 2A512B: Helicopter/Tiltrotor Aircraft Maintenance Helper, H-60
# 2025-03-30 21:39:16,516 - INFO - Processing AFSC 2A531A: Airlift/Special Mission Aircraft Maintenance Apprentice, C-20/C-21/C-22/C-37/C-40/E-4/VC-25
# 2025-03-30 21:39:16,591 - INFO - Processing AFSC 2A531B: Airlift/Special Mission Aircraft Maintenance Apprentice, C-130/C-27J
# 2025-03-30 21:39:16,662 - INFO - Processing AFSC 2A531C: Airlift/Special Mission Aircraft Maintenance Apprentice, C-5
# 2025-03-30 21:39:16,730 - INFO - Processing AFSC 2A531D: Airlift/Special Mission Aircraft Maintenance Apprentice, C-17
# 2025-03-30 21:39:16,799 - INFO - Processing AFSC 2A532B: Helicopter/Tiltrotor Aircraft Maintenance Apprentice, H-60
# 2025-03-30 21:39:16,867 - INFO - Processing AFSC 2A571: Airlift/Special Mission Aircraft Maintenance Craftsman
# 2025-03-30 21:39:16,946 - INFO - Processing AFSC 2A572: Helicopter/Tiltrotor Aircraft Maintenance Craftsman
# 2025-03-30 21:39:17,021 - INFO - Processing AFSC 2A590: Airlift/Special Mission Aircraft Maintenance Superintendent
# 2025-03-30 21:39:17,096 - INFO - Processing AFSC 2A600: Aircraft Systems Manager
# 2025-03-30 21:39:17,162 - INFO - Processing AFSC 2A611C: Aerospace Propulsion Helper, TF33, CF6, F103, F108, F117, TFE-731, TF39, PW 2040, F138 Jet Engines (Airlift, Special Mission, and B-52 aircraft)
# 2025-03-30 21:39:17,264 - INFO - Processing AFSC 2A611D: Aerospace Propulsion Helper, F100, F119, F135Jet Engines (F-15, F16, F-22 aircraft)
# 2025-03-30 21:39:17,345 - INFO - Processing AFSC 2A611E: Aerospace Propulsion Helper, F101, F110, F118, TF34 Jet Engines (A-10, B-1, B-2, F-16, U-2 aircraft)
# 2025-03-30 21:39:17,433 - INFO - Processing AFSC 2A612: Aerospace Ground Equipment Helper
# 2025-03-30 21:39:17,500 - INFO - Processing AFSC 2A613: Aircrew Egress Systems Helper
# 2025-03-30 21:39:17,566 - INFO - Processing AFSC 2A614: Aircraft Fuel Systems Helper
# 2025-03-30 21:39:17,630 - INFO - Processing AFSC 2A615: Aircraft Hydraulic Systems Helper
# 2025-03-30 21:39:17,694 - INFO - Processing AFSC 2A616: Aircraft Electrical And Environmental Systems Helper
# 2025-03-30 21:39:17,762 - INFO - Processing AFSC 2A631C: Aerospace Propulsion Apprentice, TF33, CF6, F103, F108, F117, TFE-731, TF39, PW 2040, F138 Jet Engines (Airlift, Special Mission, and B-52 aircraft)
# 2025-03-30 21:39:17,862 - INFO - Processing AFSC 2A631D: Aerospace Propulsion Apprentice, F100, F119, F135Jet Engines (F-15, F16, F-22 aircraft)
# 2025-03-30 21:39:17,944 - INFO - Processing AFSC 2A631E: Aerospace Propulsion Apprentice, F101, F110, F118, TF34 Jet Engines (A-10, B-1, B-2, F-16, U-2 aircraft)
# 2025-03-30 21:39:18,033 - INFO - Processing AFSC 2A632: Aerospace Ground Equipment Apprentice
# 2025-03-30 21:39:18,100 - INFO - Processing AFSC 2A633: Aircrew Egress Systems Apprentice
# 2025-03-30 21:39:18,166 - INFO - Processing AFSC 2A634: Aircraft Fuel Systems Apprentice
# 2025-03-30 21:39:18,231 - INFO - Processing AFSC 2A635: Aircraft Hydraulic Systems Apprentice
# 2025-03-30 21:39:18,293 - INFO - Processing AFSC 2A636: Aircraft Electrical And Environmental Systems Apprentice
# 2025-03-30 21:39:18,362 - INFO - Processing AFSC 2A652: Aerospace Ground Equipment Journeyman
# 2025-03-30 21:39:18,430 - INFO - Processing AFSC 2A653: Aircrew Egress Systems Journeyman
# 2025-03-30 21:39:18,496 - INFO - Processing AFSC 2A654: Aircraft Fuel Systems Journeyman
# 2025-03-30 21:39:18,557 - INFO - Processing AFSC 2A655: Aircraft Hydraulic Systems Journeyman
# 2025-03-30 21:39:18,621 - INFO - Processing AFSC 2A656: Aircraft Electrical And Environmental Systems Journeyman
# 2025-03-30 21:39:18,688 - INFO - Processing AFSC 2A672: Aerospace Ground Equipment Craftsman
# 2025-03-30 21:39:18,754 - INFO - Processing AFSC 2A673: Aircrew Egress Systems Craftsman
# ...
# 2025-03-30 21:43:00,021 - INFO - Processing AFSC 1A138Z: Executive Mission Aviator Apprentice, EMA Data Mask
# 2025-03-30 21:43:00,085 - INFO - Processing AFSC 1A158: Executive Mission Aviator Journeyman
# 2025-03-30 21:43:00,145 - INFO - Processing AFSC 1A158A: Executive Mission Aviator Journeyman, C-32/C-40 Flight Attendant
# 2025-03-30 21:43:00,212 - INFO - Processing AFSC 1A158B: Executive Mission Aviator Journeyman, C-32/C-40 Communications Systems Operator
# 2025-03-30 21:43:00,283 - INFO - Processing AFSC 1A158C: Executive Mission Aviator Journeyman, C-37 Flight Attendant
# 2025-03-30 21:43:00,360 - INFO - Processing AFSC 1A158D: Executive Mission Aviator Journeyman, C-37 Flight Engineer
# 2025-03-30 21:43:00,427 - INFO - Processing AFSC 1A158F: Executive Mission Aviator Journeyman, C-37 Communications Systems Operator
# 2025-03-30 21:43:00,503 - INFO - Processing AFSC 1A158G: Executive Mission Aviator Journeyman, E-4 Flight Engineer
# 2025-03-30 21:43:00,569 - INFO - Processing AFSC 1A158H: Executive Mission Aviator Journeyman, E-4 Flight Attendant
# 2025-03-30 21:43:00,632 - INFO - Processing AFSC 1A158I: Executive Mission Aviator Journeyman, E-4 Communications Systems Operator / Technician / Controller
# 2025-03-30 21:43:00,704 - INFO - Processing AFSC 1A158J: Executive Mission Aviator Journeyman, Presidential Airlift Group, Flight Engineer
# 2025-03-30 21:43:00,780 - INFO - Processing AFSC 1A158K: Executive Mission Aviator Journeyman, Presidential Airlift Group, Flight Attendant
# 2025-03-30 21:43:00,852 - INFO - Processing AFSC 1A158L: Executive Mission Aviator Journeyman, Presidential Airlift Group, Communication System Operator
# 2025-03-30 21:43:00,928 - INFO - Processing AFSC 1A158Z: Executive Mission Aviator Journeyman, EMA Data Mask
# 2025-03-30 21:43:00,992 - INFO - Processing AFSC 1A178: Executive Mission Aviator Craftsman
# 2025-03-30 21:43:01,051 - INFO - Processing AFSC 1A178A: Executive Mission Aviator Craftsman, C-32/C-40 Flight Attendant
# 2025-03-30 21:43:01,118 - INFO - Processing AFSC 1A178B: Executive Mission Aviator Craftsman, C-32/C-40 Communications Systems Operator
# 2025-03-30 21:43:01,186 - INFO - Processing AFSC 1A178C: Executive Mission Aviator Craftsman, C-37 Flight Attendant
# 2025-03-30 21:43:01,252 - INFO - Processing AFSC 1A178D: Executive Mission Aviator Craftsman, C-37 Flight Engineer
# 2025-03-30 21:43:01,321 - INFO - Processing AFSC 1A178F: Executive Mission Aviator Craftsman, C-37 Communications Systems Operator
# 2025-03-30 21:43:01,389 - INFO - Processing AFSC 1A178G: Executive Mission Aviator Craftsman, E-4 Flight Engineer
# 2025-03-30 21:43:01,456 - INFO - Processing AFSC 1A178H: Executive Mission Aviator Craftsman, E-4 Flight Attendant
# 2025-03-30 21:43:01,520 - INFO - Processing AFSC 1A178I: Executive Mission Aviator Craftsman, E-4 Communications Systems Operator / Technician / Controller
# 2025-03-30 21:43:01,594 - INFO - Processing AFSC 1A178J: Executive Mission Aviator Craftsman, Presidential Airlift Group, Flight Engineer
# 2025-03-30 21:43:01,668 - INFO - Processing AFSC 1A178K: Executive Mission Aviator Craftsman, Presidential Airlift Group, Flight Attendant
# 2025-03-30 21:43:01,742 - INFO - Processing AFSC 1A178L: Executive Mission Aviator Craftsman, Presidential Airlift Group, Communication System Operator
# 2025-03-30 21:43:01,821 - INFO - Processing AFSC 1A178Z: Executive Mission Aviator Craftsman, EMA Data Mask
# 2025-03-30 21:43:01,884 - INFO - Processing AFSC 1A198: Executive Mission Aviator Senior Enlisted Leader
# 2025-03-30 21:43:01,951 - INFO - Processing AFSC 1A198A: Executive Mission Aviator Senior Enlisted Leader, C-32/C-40 Flight Attendant
# 2025-03-30 21:43:02,025 - INFO - Processing AFSC 1A198B: Executive Mission Aviator Senior Enlisted Leader, C-32/C-40 Communications Systems Operator
# 2025-03-30 21:43:02,101 - INFO - Processing AFSC 1A198C: Executive Mission Aviator Senior Enlisted Leader, C-37 Flight Attendant
# 2025-03-30 21:43:02,177 - INFO - Processing AFSC 1A198D: Executive Mission Aviator Senior Enlisted Leader, C-37 Flight Engineer
# 2025-03-30 21:43:02,250 - INFO - Processing AFSC 1A198F: Executive Mission Aviator Senior Enlisted Leader, C-37 Communications Systems Operator
# 2025-03-30 21:43:02,330 - INFO - Processing AFSC 1A198G: Executive Mission Aviator Senior Enlisted Leader, E-4 Flight Engineer
# 2025-03-30 21:43:02,401 - INFO - Processing AFSC 1A198H: Executive Mission Aviator Senior Enlisted Leader, E-4 Flight Attendant
# 2025-03-30 21:43:02,474 - INFO - Processing AFSC 1A198I: Executive Mission Aviator Senior Enlisted Leader, E-4 Communications Systems Operator / Technician / Controller
# 2025-03-30 21:43:02,557 - INFO - Processing AFSC 1A198J: Executive Mission Aviator Senior Enlisted Leader, Presidential Airlift Group, Flight Engineer
# 2025-03-30 21:43:02,638 - INFO - Processing AFSC 1A198K: Executive Mission Aviator Senior Enlisted Leader, Presidential Airlift Group, Flight Attendant
# 2025-03-30 21:43:02,718 - INFO - Processing AFSC 1A198L: Executive Mission Aviator Senior Enlisted Leader, Presidential Airlift Group, Communication System Operator
# 2025-03-30 21:43:02,810 - INFO - Processing AFSC 1A198Z: Executive Mission Aviator Senior Enlisted Leader, EMA Data Mask
# 2025-03-30 21:43:02,878 - INFO - Processing AFSC 1A100M: Mobility Force Aviator Manager, Mobility Force Aviator
# 2025-03-30 21:43:02,946 - INFO - Processing AFSC 1A100S: Mobility Force Aviator Manager, Special Mission Aviator
# 2025-03-30 21:43:03,016 - INFO - Processing AFSC 1A100E: Mobility Force Aviator Manager, Executive Mission Aviator
# 2025-03-30 21:43:03,088 - INFO - Processing AFSC 2R200: Maintenance Management Manager
# 2025-03-30 21:43:03,151 - INFO - Processing AFSC 2R251: Maintenance Management Journeyman
# 2025-03-30 21:43:03,215 - INFO - Processing AFSC 2R271: Maintenance Management Craftsman
# 2025-03-30 21:43:03,282 - INFO - Processing AFSC 2R291: Maintenance Management Superintendent
# 2025-03-30 21:43:03,347 - INFO - Processing AFSC 2A514H: Refuel/Bomber Aircraft Maintenance Helper, B-21
# 2025-03-30 21:43:03,414 - INFO - Processing AFSC 2A534H: Refuel/Bomber Aircraft Maintenance Apprentice, B-21
# 2025-03-30 21:43:03,480 - INFO - Processing AFSC 2A554H: Refuel/Bomber Aircraft Maintenance Journeyman, B-21
# 2025-03-30 21:43:03,547 - INFO - Processing AFSC 2A051: Avionics Test Station, Components, And Electronic Warfare Systems Journeyman
# 2025-03-30 21:43:03,643 - INFO - Processing AFSC 2A071: Avionics Test Station, Components, And Electronic Warfare Systems Craftsman
# 2025-03-30 21:43:03,730 - INFO - Processing AFSC 17S1T: Cyberspace Effects Operations, Technical Track
# 2025-03-30 21:43:03,801 - INFO - Processing AFSC 17S2T: Cyberspace Effects Operations, Technical Track
# 2025-03-30 21:43:03,870 - INFO - Processing AFSC 17S3T: Cyberspace Effects Operations, Technical Track
# 2025-03-30 21:43:03,941 - INFO - Processing AFSC 17S4T: Cyberspace Effects Operations, Technical Track
# 2025-03-30 21:43:04,010 - INFO - Processing AFSC 44P1C: Psychiatrist, Addictions Psychiatry
# 2025-03-30 21:43:04,072 - INFO - Processing AFSC 44P1D: Psychiatrist, Psychosomatic Psychiatry
# 2025-03-30 21:43:04,127 - INFO - Processing AFSC 44P3C: Psychiatrist, Addictions Psychiatry
# 2025-03-30 21:43:04,179 - INFO - Processing AFSC 44P3D: Psychiatrist, Psychosomatic Psychiatry
# 2025-03-30 21:43:04,230 - INFO - Processing AFSC 44P4C: Psychiatrist, Addictions Psychiatry
# 2025-03-30 21:43:04,284 - INFO - Processing AFSC 44P4D: Psychiatrist, Psychosomatic Psychiatry
# 2025-03-30 21:43:04,340 - INFO - Processing AFSC 44P1E: Psychiatrist, Neuropsychiatry
# 2025-03-30 21:43:04,390 - INFO - Processing AFSC 44P3E: Psychiatrist, Neuropsychiatry
# 2025-03-30 21:43:04,438 - INFO - Processing AFSC 44P4E: Psychiatrist, Neuropsychiatry
# 2025-03-30 21:43:04,487 - INFO - Processing AFSC 48O1: Aeromedical Physician
# 2025-03-30 21:43:04,542 - INFO - Processing AFSC 48O3: Aeromedical Physician
# 2025-03-30 21:43:04,595 - INFO - Processing AFSC 48O4: Aeromedical Physician
# 2025-03-30 21:43:04,651 - INFO - Processing AFSC 88Y0: Pathfinder Officer
# 2025-03-30 21:43:04,705 - INFO - Processing AFSC 11K1M: Trainer Pilot, AETC Air Mobility Fundamentals Course Instructor
# 2025-03-30 21:43:04,781 - INFO - Processing AFSC 17W1: Warfighter Communications & IT Systems Operations
# 2025-03-30 21:43:04,846 - INFO - Processing AFSC 17W3: Warfighter Communications & IT Systems Operations
# 2025-03-30 21:43:04,910 - INFO - Processing AFSC 17W4: Warfighter Communications & IT Systems Operations
# 2025-03-30 21:43:04,989 - INFO - Processing AFSC 17W1C: Warfighter Communications & IT Systems Operations, Cybersecurity Specialist
# 2025-03-30 21:43:05,062 - INFO - Processing AFSC 17W3C: Warfighter Communications & IT Systems Operations, Cybersecurity Specialist
# 2025-03-30 21:43:05,148 - INFO - Processing AFSC 17W4C: Warfighter Communications & IT Systems Operations, Cybersecurity Specialist
# 2025-03-30 21:43:05,219 - INFO - Processing AFSC 17W1D: Warfighter Communications & IT Systems Operations, Data Operations Specialist
# 2025-03-30 21:43:05,297 - INFO - Processing AFSC 17W3D: Warfighter Communications & IT Systems Operations, Data Operations Specialist
# 2025-03-30 21:43:05,376 - INFO - Processing AFSC 17W4D: Warfighter Communications & IT Systems Operations, Data Operations Specialist
# 2025-03-30 21:43:05,450 - INFO - Processing AFSC 17W1I: Warfighter Communications & IT Systems Operations, Information Technology Specialist
# 2025-03-30 21:43:05,528 - INFO - Processing AFSC 17W3I: Warfighter Communications & IT Systems Operations, Information Technology Specialist
# 2025-03-30 21:43:05,605 - INFO - Processing AFSC 17W4I: Warfighter Communications & IT Systems Operations, Information Technology Specialist
# 2025-03-30 21:43:05,682 - INFO - Processing AFSC 17Y1: Cyber Effects & Warfare Operations
# 2025-03-30 21:43:05,751 - INFO - Processing AFSC 17Y3: Cyber Effects & Warfare Operations
# 2025-03-30 21:43:05,823 - INFO - Processing AFSC 17Y4: Cyber Effects & Warfare Operations
# 2025-03-30 21:43:05,889 - INFO - Processing AFSC 11K3M: Trainer Pilot, AETC Air Mobility Fundamentals Course Instructor
# 2025-03-30 21:43:05,971 - INFO - Processing AFSC 11K4M: Trainer Pilot, AETC Air Mobility Fundamentals Course Instructor
# 2025-03-30 21:43:06,050 - INFO - Processing AFSC 13B3X: Air Battle Manager, Flight Test
# 2025-03-30 21:43:06,110 - INFO - Processing AFSC 13B4X: Air Battle Manager, Flight Test
# 2025-03-30 21:43:06,167 - INFO - Processing AFSC 91E0: Wing Commander Equivalent
# 2025-03-30 21:43:06,224 - INFO - Processing AFSC 2A914: Heavy Aircraft Integrated Avionics Helper
# 2025-03-30 21:43:06,285 - INFO - Processing AFSC 2A934: Heavy Aircraft Integrated Avionics Apprentice
# 2025-03-30 21:43:06,346 - INFO - Processing AFSC 44E1E: Emergency Medicine Physician, Emergency Medicine Services Physician
# 2025-03-30 21:43:06,409 - INFO - Processing AFSC 44E3E: Emergency Medicine Physician, Emergency Medicine Services Physician
# 2025-03-30 21:43:06,470 - INFO - Processing AFSC 17Y1A: Cyber Effects & Warfare Operations, Cyber Warfare Analyst
# 2025-03-30 21:43:06,541 - INFO - Processing AFSC 17Y3A: Cyber Effects & Warfare Operations, Cyber Warfare Analyst
# 2025-03-30 21:43:06,613 - INFO - Processing AFSC 17Y4A: Cyber Effects & Warfare Operations, Cyber Warfare Analyst
# 2025-03-30 21:43:06,683 - INFO - Processing AFSC 17Y1C: Cyber Effects & Warfare Operations, Cyber Capability Developer
# 2025-03-30 21:43:06,756 - INFO - Processing AFSC 17Y3C: Cyber Effects & Warfare Operations, Cyber Capability Developer
# 2025-03-30 21:43:06,832 - INFO - Processing AFSC 17Y4C: Cyber Effects & Warfare Operations, Cyber Capability Developer
# 2025-03-30 21:43:06,905 - INFO - Processing AFSC 17Y1D: Cyber Effects & Warfare Operations, Cyber Threat Defense Analyst
# 2025-03-30 21:43:06,981 - INFO - Processing AFSC 17Y3D: Cyber Effects & Warfare Operations, Cyber Threat Defense Analyst
# 2025-03-30 21:43:07,058 - INFO - Processing AFSC 17Y4D: Cyber Effects & Warfare Operations, Cyber Threat Defense Analyst
# 2025-03-30 21:43:07,132 - INFO - Processing AFSC 17Y1O: Cyber Effects & Warfare Operations, Cyber Attack Operator
# 2025-03-30 21:43:07,204 - INFO - Processing AFSC 17Y3O: Cyber Effects & Warfare Operations, Cyber Attack Operator
# 2025-03-30 21:43:07,285 - INFO - Processing AFSC 17Y4O: Cyber Effects & Warfare Operations, Cyber Attack Operator
# 2025-03-30 21:43:07,358 - INFO - Processing AFSC 17Y1I: Cyber Effects & Warfare Operations, Cyber Threat Defense Integrator
# 2025-03-30 21:43:07,435 - INFO - Processing AFSC 17Y3I: Cyber Effects & Warfare Operations, Cyber Threat Defense Integrator
# 2025-03-30 21:43:07,512 - INFO - Processing AFSC 17Y4I: Cyber Effects & Warfare Operations, Cyber Threat Defense Integrator
# 2025-03-30 21:43:07,590 - INFO - Processing AFSC 44E4E: Emergency Medicine Physician, Emergency Medicine Services Physician
# 2025-03-30 21:43:07,656 - INFO - Processing AFSC 44N1B: Neurologist, Pain Management
# 2025-03-30 21:43:07,708 - INFO - Processing AFSC 44N3B: Neurologist, Pain Management
# 2025-03-30 21:43:07,761 - INFO - Processing AFSC 44N4B: Neurologist, Pain Management
# 2025-03-30 21:43:07,814 - INFO - Processing AFSC 44P1F: Psychiatrist, Sleep Pathology
# 2025-03-30 21:43:07,868 - INFO - Processing AFSC 44P3F: Psychiatrist, Sleep Pathology
# 2025-03-30 21:43:07,925 - INFO - Processing AFSC 44P4F: Psychiatrist, Sleep Pathology
# 2025-03-30 21:43:07,976 - INFO - Processing AFSC 48A1X: Aerospace Medicine Physician Specialist, Space Medical Operations Experienced
# 2025-03-30 21:43:08,050 - INFO - Processing AFSC 48A3X: Aerospace Medicine Physician Specialist, Space Medical Operations Experienced
# 2025-03-30 21:43:08,125 - INFO - Processing AFSC 48A4X: Aerospace Medicine Physician Specialist, Space Medical Operations Experienced
# 2025-03-30 21:43:08,199 - INFO - Processing AFSC 48G1X: General Medicine Officer (GMO) Flight Surgeon, Space Medical Operations Experienced
# 2025-03-30 21:43:08,278 - INFO - Processing AFSC 48G3X: General Medicine Officer (GMO) Flight Surgeon, Space Medical Operations Experienced
# 2025-03-30 21:43:08,355 - INFO - Processing AFSC 48G4X: General Medicine Officer (GMO) Flight Surgeon, Space Medical Operations Experienced
# 2025-03-30 21:43:08,434 - INFO - Processing AFSC 48R1X: Residency Trained Flight Surgeon, Space Medical Operations Experienced
# 2025-03-30 21:43:08,511 - INFO - Processing AFSC 12K1Q: Trainer Combat Systems Officer, T-7
# 2025-03-30 21:43:08,581 - INFO - Processing AFSC 48R3X: Residency Trained Flight Surgeon, Space Medical Operations Experienced
# 2025-03-30 21:43:08,657 - INFO - Processing AFSC 48R4X: Residency Trained Flight Surgeon, Space Medical Operations Experienced
# 2025-03-30 21:43:08,733 - INFO - Processing AFSC 88M0: United States Air Force Medical Pinnacle Position
# 2025-03-30 21:43:08,804 - INFO - Processing AFSC 2A914A: Heavy Aircraft Integrated Avionics Helper, C4ISR Mission Systems (E-3, E-4, E-7, EC-130H, RC-135, VC-25)
# 2025-03-30 21:43:08,889 - INFO - Processing AFSC 2A934A: Heavy Aircraft Integrated Avionics Apprentice, C4ISR Mission Systems (E-3, E-4, E-7, EC-130H, RC-135, VC-25)
# 2025-03-30 21:43:08,976 - INFO - Processing AFSC 2R211: Maintenance Management Helper
# 2025-03-30 21:43:09,041 - INFO - Processing AFSC 2R231: Maintenance Management Apprentice
# 2025-03-30 21:43:09,107 - INFO - Processing AFSC 3P071B: Security Forces Craftsman, Combat Arms
# 2025-03-30 21:43:09,175 - INFO - Processing AFSC 12K3Q: Trainer Combat Systems Officer, T-7
# 2025-03-30 21:43:09,243 - INFO - Processing AFSC 12K4Q: Trainer Combat Systems Officer, T-7
# 2025-03-30 21:43:09,315 - INFO - Created skill mappings for 4020 AFSCs
# 2025-03-30 21:43:09,316 - INFO - Creating final taxonomy data structure
# 2025-03-30 21:43:14,051 - INFO - Saved merged taxonomy to C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\military_skills_taxonomy.json
# 2025-03-30 21:43:14,052 - INFO - Military Skills Taxonomy creation process completed successfully

# %%
# Load the existing taxonomy data
import json
import os

# Define the path to your existing taxonomy JSON
INPUT_FILE = r"C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\military_skills_taxonomy.json"
OUTPUT_FILE = r"C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\enhanced_military_skills_taxonomy.json"

# Load the data
with open(INPUT_FILE, 'r', encoding='utf-8') as f:
    taxonomy_data = json.load(f)

print(f"Loaded taxonomy with {len(taxonomy_data['afscCategories'])} AFSC categories")

# Define all enhancement functions
def enhance_data_quality(afscs):
    """Filter out low-quality or irrelevant matches"""
    for afsc in afscs:
        if 'matchedSkills' in afsc:
            # Filter out very low scoring matches
            afsc['matchedSkills'] = [skill for skill in afsc['matchedSkills'] if skill.get('matchScore', 0) >= 4]
            
            # Filter out likely domain mismatches (ship/naval related for Air Force)
            filtered_skills = []
            for skill in afsc['matchedSkills']:
                description = skill.get('description', '').lower()
                skill_name = skill.get('skillName', '').lower()
                
                # Check for competing domain terminology
                competing_domains = ['ship', 'vessel', 'maritime', 'naval', 'ocean', 'seaman']
                if any(term in description or term in skill_name for term in competing_domains):
                    # Only keep if the score is very high despite the competing domain terms
                    if skill.get('matchScore', 0) >= 10:
                        filtered_skills.append(skill)
                else:
                    filtered_skills.append(skill)
            
            afsc['matchedSkills'] = filtered_skills
    
    return afscs

def enhance_military_context(afscs):
    """Add military-specific context to improve LLM understanding"""
    
    # Military service mapping
    service_context = {
        'Air Force': {
            'mission': 'Fly, fight and win in air, space and cyberspace',
            'domains': ['air', 'space', 'cyberspace'],
            'key_capabilities': ['air superiority', 'global strike', 'rapid mobility', 
                                'intelligence gathering', 'command and control']
        }
    }
    
    # AFSC prefix/category mapping
    afsc_categories = {
        '1': 'Operations',
        '2': 'Logistics and Maintenance',
        '3': 'Support',
        '4': 'Medical and Dental',
        '5': 'Legal and Chaplain',
        '6': 'Acquisition and Financial Management',
        '7': 'Special Investigations',
        '8': 'Special Duty and Reporting Identifiers',
        '9': 'Special Duty and Reporting Identifiers'
    }
    
    for afsc in afscs:
        # Add service context
        afsc['serviceContext'] = service_context['Air Force']
        
        # Add AFSC category context
        if 'afscCode' in afsc and afsc['afscCode']:
            prefix = afsc['afscCode'][0]
            if prefix in afsc_categories:
                afsc['afscCategory'] = afsc_categories[prefix]
                afsc['afscCategoryDescription'] = f"This AFSC belongs to the {afsc_categories[prefix]} category of Air Force specialties."
    
    return afscs

def enhance_verb_analysis(afscs):
    """Improve verb extraction and grouping for better action analysis"""
    
    # Define verb synonyms for grouping related actions
    verb_groups = {
        'analyze': ['analyze', 'assess', 'evaluate', 'examine', 'inspect', 'investigate', 'review'],
        'manage': ['manage', 'administer', 'coordinate', 'direct', 'oversee', 'supervise'],
        'develop': ['develop', 'create', 'design', 'establish', 'formulate', 'generate'],
        'implement': ['implement', 'apply', 'deploy', 'execute', 'perform', 'use'],
        'communicate': ['communicate', 'advise', 'inform', 'instruct', 'present', 'report'],
        'operate': ['operate', 'control', 'drive', 'handle', 'navigate', 'pilot']
    }
    
    # Create reverse mapping for quick lookup
    verb_to_group = {}
    for group, verbs in verb_groups.items():
        for verb in verbs:
            verb_to_group[verb] = group
    
    for afsc in afscs:
        if 'matchedSkills' in afsc:
            # Advanced verb extraction with fallback
            for skill in afsc['matchedSkills']:
                # Use existing verb field, but enhance it
                verb = skill.get('verb', '').lower() if skill.get('verb') else ''
                
                # Assign to verb group if it exists
                if verb in verb_to_group:
                    skill['verbGroup'] = verb_to_group[verb]
                else:
                    skill['verbGroup'] = 'other'
            
            # Create skills by verb group instead of just verb
            skills_by_verb_group = {}
            for skill in afsc['matchedSkills']:
                group = skill.get('verbGroup', 'other')
                if group not in skills_by_verb_group:
                    skills_by_verb_group[group] = []
                skills_by_verb_group[group].append(skill)
            
            # Add to AFSC data
            afsc['skillsByVerbGroup'] = [
                {
                    'verbGroup': group,
                    'commonVerbs': list(set(skill.get('verb', '') for skill in skills if skill.get('verb', ''))),
                    'skills': skills
                }
                for group, skills in skills_by_verb_group.items()
            ]
    
    return afscs

def refine_relevance_scores(afscs):
    """Refine relevance scores to better prioritize directly applicable skills"""
    
    for afsc in afscs:
        if 'matchedSkills' in afsc:
            for skill in afsc['matchedSkills']:
                # Normalize score to 0-100 scale for better LLM understanding
                match_score = skill.get('matchScore', 0)
                normalized_score = min(match_score * 10, 100)
                
                # Add confidence level based on score
                if normalized_score >= 80:
                    confidence = "high"
                elif normalized_score >= 50:
                    confidence = "medium"
                else:
                    confidence = "low"
                
                # Update skill data
                skill['relevance'] = normalized_score
                skill['confidenceLevel'] = confidence
            
            # Re-sort skills by new normalized relevance score
            if len(afsc['matchedSkills']) > 0:
                afsc['matchedSkills'].sort(key=lambda x: x.get('relevance', 0), reverse=True)
    
    return afscs

def create_llm_optimized_taxonomy(taxonomy_data):
    """Create an LLM-optimized taxonomy structure with clear relationships"""
    
    optimized_taxonomy = {
        "metadata": {
            "title": "Air Force Skills Taxonomy",
            "description": "A hierarchical taxonomy of skills for Air Force Specialty Codes (AFSCs)",
            "purpose": "This taxonomy maps military occupational specialties to their required skills and capabilities",
            "structure": "This taxonomy is organized in the following hierarchy: AFSC Categories > Individual AFSCs > Skill Categories > Skills"
        },
        "afscCategories": {}
    }
    
    # Process each AFSC category
    for category in taxonomy_data['afscCategories']:
        category_name = category['categoryName']
        optimized_taxonomy["afscCategories"][category_name] = {
            "name": category_name,
            "afscs": []
        }
        
        # Process each AFSC in this category
        for afsc in category['afscs']:
            if 'afscCode' not in afsc:
                continue
                
            # Create simplified AFSC entry optimized for LLM comprehension
            simplified_afsc = {
                "code": afsc.get('afscCode', ''),
                "title": afsc.get('afscTitle', ''),
                "description": afsc.get('description', ''),
                "category": afsc.get('afscCategory', ''),
                "skillSummary": "This AFSC requires capabilities in the following areas:",
                "coreVerbs": [],
                "coreSkills": []
            }
            
            # Add top verb groups
            for verb_group in afsc.get('skillsByVerbGroup', []):
                if len(simplified_afsc["coreVerbs"]) < 5:  # Limit to top 5
                    simplified_afsc["coreVerbs"].append(verb_group['verbGroup'])
            
            # Add top skills
            top_skills = sorted(afsc.get('matchedSkills', []), 
                              key=lambda x: x.get('relevance', x.get('matchScore', 0)), 
                              reverse=True)[:10]  # Top 10 skills
            
            for skill in top_skills:
                simplified_afsc["coreSkills"].append({
                    "name": skill.get('skillName', ''),
                    "action": skill.get('verb', ''),
                    "relevance": skill.get('relevance', 0),
                    "confidence": skill.get('confidenceLevel', 'medium')
                })
            
            # Add to taxonomy
            optimized_taxonomy["afscCategories"][category_name]["afscs"].append(simplified_afsc)
    
    return optimized_taxonomy

# Function to apply all enhancements
def apply_enhancements(taxonomy_data):
    """Apply all enhancements to the taxonomy data"""
    enhanced_data = taxonomy_data.copy()
    
    # Process each AFSC category
    for category_idx, category in enumerate(enhanced_data['afscCategories']):
        category_name = category['categoryName']
        print(f"Enhancing {category_name} category...")
        
        # Apply enhancements to each AFSC in this category
        category['afscs'] = enhance_data_quality(category['afscs'])
        category['afscs'] = enhance_military_context(category['afscs'])
        category['afscs'] = enhance_verb_analysis(category['afscs'])
        category['afscs'] = refine_relevance_scores(category['afscs'])
    
    # Create optimized structure
    enhanced_data['llm_optimized_structure'] = create_llm_optimized_taxonomy(enhanced_data)
    
    return enhanced_data

# Apply the enhancements
enhanced_taxonomy = apply_enhancements(taxonomy_data)

# Save the enhanced taxonomy
with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
    json.dump(enhanced_taxonomy, f, indent=2)

print(f"Enhanced taxonomy saved to {OUTPUT_FILE}")
# Out:
# Loaded taxonomy with 3 AFSC categories
# Enhancing Enlisted category...
# Enhancing Officer category...
# Enhancing Warrant category...
# Enhanced taxonomy saved to C:\Users\Kyle\Desktop\Grad School\IS Demo\Phase 2 Rebuild\enhanced_military_skills_taxonomy.json
